# %%
pip install --upgrade --force-reinstall numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.1 MB/s eta 0:00:00
# Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 132.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# Successfully installed numpy-2.3.4

# %%
pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 124.3 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
pip install --upgrade --force-reinstall torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.9.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.9.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting setuptools (from torch)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.0 (from torch)
#   Downloading triton-3.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.9.0-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 156.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 29.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 66.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 38.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 66.8 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 20.9 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.5 MB/s eta 0:00:00
# Downloading triton-3.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 5.3 MB/s eta 0:00:00
# Downloading torchvision-0.24.0-cp312-cp312-manylinux_2_28_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 131.0 MB/s eta 0:00:00
# Downloading torchaudio-2.9.0-cp312-cp312-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.5 MB/s eta 0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 19.8 MB/s eta 0:00:00
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 96.5 MB/s eta 0:00:00
# Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 137.9 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 149.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.1 MB/s eta 0:00:00
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 13.1 MB/s eta 0:00:00
# Using cached numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.9 MB/s eta 0:00:00
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 40.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, sympy, setuptools, pillow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.11.1.6
#     Uninstalling nvidia-cufile-cu12-1.11.1.6:
#       Successfully uninstalled nvidia-cufile-cu12-1.11.1.6
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0+cu126
#     Uninstalling torchvision-0.23.0+cu126:
#       Successfully uninstalled torchvision-0.23.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.8.0+cu126
#     Uninstalling torchaudio-2.8.0+cu126:
#       Successfully uninstalled torchaudio-2.8.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# fastai 2.8.4 requires torch<2.9,>=1.10, but you have torch 2.9.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# gradio 5.49.1 requires pillow<12.0,>=8.0, but you have pillow 12.0.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.0 fsspec-2025.9.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.4 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 pillow-12.0.0 setuptools-80.9.0 sympy-1.14.0 torch-2.9.0 torchaudio-2.9.0 torchvision-0.24.0 triton-3.5.0 typing-extensions-4.15.0

# %%
pip install torchcam
# Out:
# Collecting torchcam
#   Downloading torchcam-0.4.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (2.9.0)
# Collecting numpy<2.0.0,>=1.17.2 (from torchcam)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: Pillow!=9.2.0,>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (12.0.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.0->torchcam) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->torchcam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->torchcam) (3.0.3)
# Downloading torchcam-0.4.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy, torchcam
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.4 requires torch<2.9,>=1.10, but you have torch 2.9.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.49.1 requires pillow<12.0,>=8.0, but you have pillow 12.0.0 which is incompatible.
# Successfully installed numpy-1.26.4 torchcam-0.4.0

# %%
# !pip install torchcam timm --quiet

# %%
pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.20)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.9.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.24.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.35.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2025.10.5)

# %%
# Complete APTOS Federated Learning with ViT
# Generates: Accuracy, F1, AUC, Time, Expert Entropy, Parameters, Communication Costs, ROC, Confusion Matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchvision import transforms, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (accuracy_score, f1_score, recall_score,
                            confusion_matrix, classification_report,
                            roc_curve, auc)
from sklearn.preprocessing import label_binarize # Import label_binarize from preprocessing
import os
import time
import copy
import gc
import pandas as pd
import timm
from PIL import Image
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# ==== Vision Transformer Architecture ====
class VisionTransformer(nn.Module):
    """Vision Transformer model for APTOS classification"""
    def __init__(self, num_classes=4, model_name='vit_base_patch16_224', pretrained=True, dropout_rate=0.3):
        super(VisionTransformer, self).__init__()

        # Load pretrained ViT from timm
        self.vit = timm.create_model(model_name, pretrained=pretrained, num_classes=0)

        # Get feature dimension
        self.feature_dim = self.vit.num_features

        # Enhanced classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(self.feature_dim),
            nn.Dropout(dropout_rate),
            nn.Linear(self.feature_dim, self.feature_dim // 2),
            nn.GELU(),
            nn.LayerNorm(self.feature_dim // 2),
            nn.Dropout(dropout_rate / 2),
            nn.Linear(self.feature_dim // 2, num_classes)
        )

        self.is_moe = False
        self.model_name = model_name
        self._initialize_classifier()

    def _initialize_classifier(self):
        for m in self.classifier.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        # Extract features from ViT
        features = self.vit(x)

        # Classify
        output = self.classifier(features)

        return output


class VisionTransformerMOE(nn.Module):
    """Vision Transformer with Mixture of Experts"""
    def __init__(self, num_classes=4, model_name='vit_base_patch16_224', pretrained=True,
                 dropout_rate=0.3, num_experts=4):
        super(VisionTransformerMOE, self).__init__()

        # Load pretrained ViT from timm
        self.vit = timm.create_model(model_name, pretrained=pretrained, num_classes=0)

        # Get feature dimension
        self.feature_dim = self.vit.num_features

        # MOE classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(self.feature_dim),
            nn.Dropout(dropout_rate),
            MixtureOfExperts(
                input_dim=self.feature_dim,
                hidden_dim=self.feature_dim // 2,
                output_dim=num_classes,
                num_experts=num_experts,
                dropout_rate=dropout_rate,
                top_k=2
            )
        )

        self.is_moe = True
        self.model_name = model_name

    def forward(self, x):
        # Extract features from ViT
        features = self.vit(x)

        # MOE returns (logits, gate_weights)
        return self.classifier[2](features)


# ==== MOE Components ====
class ExpertNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(ExpertNetwork, self).__init__()
        self.network = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim // 2, output_dim)
        )

    def forward(self, x):
        return self.network(x)


class GatingNetwork(nn.Module):
    def __init__(self, input_dim, num_experts, dropout_rate=0.1):
        super(GatingNetwork, self).__init__()
        self.gate = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, input_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(input_dim // 2, num_experts),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        return self.gate(x)


class MixtureOfExperts(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_experts=4, dropout_rate=0.3, top_k=2):
        super(MixtureOfExperts, self).__init__()
        self.num_experts = num_experts
        self.top_k = top_k
        self.experts = nn.ModuleList([ExpertNetwork(input_dim, hidden_dim, output_dim, dropout_rate) for _ in range(num_experts)])
        self.gate = GatingNetwork(input_dim, num_experts, dropout_rate)

    def forward(self, x):
        gate_weights = self.gate(x)
        top_k_weights, top_k_indices = torch.topk(gate_weights, self.top_k, dim=-1)
        top_k_weights = top_k_weights / top_k_weights.sum(dim=-1, keepdim=True)

        expert_outputs = torch.stack([expert(x) for expert in self.experts], dim=1)
        batch_size, output_dim = x.size(0), expert_outputs.size(-1)
        final_output = torch.zeros(batch_size, output_dim, device=x.device)

        for i in range(self.top_k):
            expert_idx = top_k_indices[:, i]
            expert_weight = top_k_weights[:, i].unsqueeze(-1)
            selected_outputs = expert_outputs[torch.arange(batch_size), expert_idx]
            final_output += expert_weight * selected_outputs

        return final_output, gate_weights


# ==== Loss Functions ====
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        return focal_loss


class MOELoss(nn.Module):
    def __init__(self, base_criterion, load_balance_weight=0.01):
        super(MOELoss, self).__init__()
        self.base_criterion = base_criterion
        self.load_balance_weight = load_balance_weight

    def forward(self, outputs, targets):
        if isinstance(outputs, tuple):
            logits, gate_weights = outputs
            base_loss = self.base_criterion(logits, targets)
        else:
            logits = outputs
            base_loss = self.base_criterion(logits, targets)
            gate_weights = None

        total_loss = base_loss

        if gate_weights is not None and self.load_balance_weight > 0:
            num_experts = gate_weights.size(-1)
            mean_gate_weights = gate_weights.mean(dim=0)
            uniform_target = torch.ones_like(mean_gate_weights) / num_experts
            load_balance_loss = nn.functional.kl_div(torch.log(mean_gate_weights + 1e-8), uniform_target, reduction='batchmean')
            total_loss += self.load_balance_weight * load_balance_loss

        return total_loss


# ==== Dataset Setup - CSV VERSION ====
def setup_aptos_dataset_from_csv(base_path, test_ratio=0.2, random_seed=42):
    """
    Setup APTOS dataset from CSV files and image folders

    Args:
        base_path: Path to folder containing train_images/, val_images/, test_images/,
                   and train_1.csv, valid.csv, test.csv
        test_ratio: Not used (kept for compatibility), we use existing val/test split
        random_seed: Random seed for reproducibility
    """
    np.random.seed(random_seed)
    torch.manual_seed(random_seed)

    print(f"\n{'='*80}")
    print(f"Loading APTOS dataset from: {base_path}")
    print(f"{'='*80}")

    # Define paths
    train_csv_path = os.path.join(base_path, 'train_1.csv')
    val_csv_path = os.path.join(base_path, 'valid.csv')
    test_csv_path = os.path.join(base_path, 'test.csv')

    train_img_dir = os.path.join(base_path, 'train_images')
    val_img_dir = os.path.join(base_path, 'val_images')
    test_img_dir = os.path.join(base_path, 'test_images')

    # Check if files exist
    if not os.path.exists(train_csv_path):
        raise FileNotFoundError(f"train_1.csv not found at {train_csv_path}")
    if not os.path.exists(train_img_dir):
        raise FileNotFoundError(f"train_images folder not found at {train_img_dir}")

    # Load CSV files
    print("\nLoading CSV files...")
    train_df = pd.read_csv(train_csv_path)
    print(f"  train_1.csv: {len(train_df)} records")

    # Use validation set if exists, otherwise split from training
    if os.path.exists(val_csv_path) and os.path.exists(val_img_dir):
        print(f"  valid.csv found: Using existing validation set")
        val_df = pd.read_csv(val_csv_path)
        use_existing_val = True
    else:
        print(f"  valid.csv not found: Will use test set for validation")
        use_existing_val = False

    # Use test set if exists
    if os.path.exists(test_csv_path) and os.path.exists(test_img_dir):
        print(f"  test.csv found: Using existing test set")
        test_df = pd.read_csv(test_csv_path)
        use_existing_test = True
    else:
        print(f"  test.csv not found: Will split from training")
        use_existing_test = False

    # Detect column names
    img_col = 'id_code' if 'id_code' in train_df.columns else ('image_id' if 'image_id' in train_df.columns else train_df.columns[0])
    label_col = 'diagnosis' if 'diagnosis' in train_df.columns else ('level' if 'level' in train_df.columns else train_df.columns[1])

    print(f"\nDetected CSV columns: image='{img_col}', label='{label_col}'")

    # Get number of classes and class names
    all_labels = train_df[label_col].values
    unique_classes = sorted(np.unique(all_labels))
    num_classes = len(unique_classes)
    class_names = [f"Class_{i}" for i in unique_classes]

    print(f"\nDataset Statistics:")
    print(f"  Number of classes: {num_classes}")
    print(f"  Class labels: {unique_classes}")

    # Prepare training samples
    train_samples = []
    missing_count = 0
    for _, row in train_df.iterrows():
        img_name = str(row[img_col])
        # Try different extensions
        for ext in ['.png', '.jpg', '.jpeg']:
            if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                test_name = img_name + ext
            else:
                test_name = img_name
            img_path = os.path.join(train_img_dir, test_name)
            if os.path.exists(img_path):
                train_samples.append((img_path, int(row[label_col])))
                break
        else:
            missing_count += 1

    if missing_count > 0:
        print(f"  ⚠ Warning: {missing_count} training images not found")
    print(f"  Training samples loaded: {len(train_samples)}/{len(train_df)}")

    # Prepare test/validation samples
    test_samples = []

    if use_existing_val:
        missing_count = 0
        for _, row in val_df.iterrows():
            img_name = str(row[img_col])
            for ext in ['.png', '.jpg', '.jpeg']:
                if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                    test_name = img_name + ext
                else:
                    test_name = img_name
                img_path = os.path.join(val_img_dir, test_name)
                if os.path.exists(img_path):
                    test_samples.append((img_path, int(row[label_col])))
                    break
            else:
                missing_count += 1
        if missing_count > 0:
            print(f"  ⚠ Warning: {missing_count} validation images not found")
        print(f"  Validation samples loaded: {len(test_samples)}/{len(val_df)}")

    elif use_existing_test:
        missing_count = 0
        for _, row in test_df.iterrows():
            img_name = str(row[img_col])
            for ext in ['.png', '.jpg', '.jpeg']:
                if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                    test_name = img_name + ext
                else:
                    test_name = img_name
                img_path = os.path.join(test_img_dir, test_name)
                if os.path.exists(img_path):
                    test_samples.append((img_path, int(row[label_col])))
                    break
            else:
                missing_count += 1
        if missing_count > 0:
            print(f"  ⚠ Warning: {missing_count} test images not found")
        print(f"  Test samples loaded: {len(test_samples)}/{len(test_df)}")

    else:
        print(f"\nCreating stratified test split ({test_ratio*100}%)...")
        train_temp = []
        for class_idx in unique_classes:
            class_samples = [(p, l) for p, l in train_samples if l == class_idx]
            np.random.shuffle(class_samples)
            n_test = max(1, int(len(class_samples) * test_ratio))
            test_samples.extend(class_samples[-n_test:])
            train_temp.extend(class_samples[:-n_test])
        train_samples = train_temp
        print(f"  Split complete: {len(train_samples)} train, {len(test_samples)} test")

    # Calculate class distribution and weights
    train_labels = [label for _, label in train_samples]
    class_counts = torch.zeros(num_classes)
    for label in train_labels:
        class_counts[label] += 1

    print(f"\nClass Distribution (Training):")
    for i, count in enumerate(class_counts):
        percentage = (count / len(train_labels)) * 100
        print(f"  {class_names[i]}: {int(count)} samples ({percentage:.1f}%)")

    # Calculate class weights for balanced training
    class_weights = 1.0 / (class_counts + 1e-8)
    class_weights = class_weights / class_weights.sum() * num_classes

    print(f"\nClass Weights (for balanced training):")
    for i, weight in enumerate(class_weights):
        print(f"  {class_names[i]}: {weight:.3f}")

    # Define transforms for ViT (224x224 standard)
    train_tfm = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    test_tfm = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Create dataset class
    class APTOSDataset(Dataset):
        def __init__(self, samples, transform=None):
            self.samples = samples
            self.transform = transform

        def __len__(self):
            return len(self.samples)

        def __getitem__(self, idx):
            from PIL import Image
            img_path, label = self.samples[idx]
            try:
                image = Image.open(img_path).convert('RGB')
                if self.transform:
                    image = self.transform(image)
                return image, label
            except Exception as e:
                print(f"Error loading {img_path}: {e}")
                # Return a black image in case of error
                if self.transform:
                    return torch.zeros(3, 224, 224), label
                else:
                    return Image.new('RGB', (224, 224)), label

    # Create datasets
    train_ds = APTOSDataset(train_samples, transform=train_tfm)
    test_ds = APTOSDataset(test_samples, transform=test_tfm)

    # Set attributes for compatibility
    train_ds.classes = test_ds.classes = class_names
    train_ds.samples = train_samples
    test_ds.samples = test_samples

    print(f"\n{'='*80}")
    print(f"Dataset Preparation Complete!")
    print(f"{'='*80}")
    print(f"  Training samples: {len(train_ds)}")
    print(f"  Test samples: {len(test_ds)}")
    print(f"  Number of classes: {num_classes}")
    print(f"  Class names: {class_names}")
    print(f"{'='*80}\n")

    return train_ds, test_ds, class_names, class_weights, num_classes


def split_noniid_aptos(labels, n_clients=4, alpha=0.5):
    """Create Non-IID split using Dirichlet distribution"""
    idxs = np.arange(len(labels))
    client_idx = [[] for _ in range(n_clients)]
    unique_classes = np.unique(labels)

    print(f"\n{'='*80}")
    print(f"Creating Non-IID Client Split")
    print(f"{'='*80}")
    print(f"  Number of clients: {n_clients}")
    print(f"  Dirichlet alpha: {alpha}")
    print(f"  Total samples: {len(labels)}")

    for c in unique_classes:
        idx_c = idxs[labels == c]
        np.random.shuffle(idx_c)
        props = np.random.dirichlet([alpha] * n_clients)
        props = props / props.sum()
        splits = (props.cumsum()[:-1] * len(idx_c)).astype(int)
        splits = np.split(idx_c, splits)
        for i in range(n_clients):
            client_idx[i] += splits[i].tolist()

    for i in range(n_clients):
        np.random.shuffle(client_idx[i])

    return client_idx


# ==== Model Creation ====
def get_vit_model(num_classes=4, model_name='vit_base_patch16_224', pretrained=True,
                  dropout_rate=0.3, use_moe=False, num_experts=4):
    """
    Create Vision Transformer model

    Available models:
    - vit_tiny_patch16_224
    - vit_small_patch16_224
    - vit_base_patch16_224
    - vit_base_patch16_384
    - vit_large_patch16_224
    """

    if use_moe:
        model = VisionTransformerMOE(
            num_classes=num_classes,
            model_name=model_name,
            pretrained=pretrained,
            dropout_rate=dropout_rate,
            num_experts=num_experts
        )
        print(f"✓ Created ViT with MOE ({num_experts} experts)")
    else:
        model = VisionTransformer(
            num_classes=num_classes,
            model_name=model_name,
            pretrained=pretrained,
            dropout_rate=dropout_rate
        )
        print("✓ Created Vision Transformer model")

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"  Model: {model_name}")
    print(f"  Total parameters: {total_params:,}")
    print(f"  Trainable parameters: {trainable_params:,}")
    print(f"  Parameters (M): {total_params / 1e6:.2f}")
    print(f"  Model size: {total_params * 4 / (1024**2):.2f} MB")

    return model


# ==== Communication Cost Tracker ====
class CommCostTracker:
    def __init__(self, model):
        self.param_count = sum(p.numel() for p in model.parameters())
        self.param_size_mb = self.param_count * 4 / (1024 ** 2)

    def get_detailed_costs(self):
        return {
            'parameters_m': self.param_count / 1e6,
            'uplink_mb': self.param_size_mb,
            'downlink_mb': self.param_size_mb,
            'total_comm_mb': self.param_size_mb * 2
        }


# ==== Training Function ====
def train_local_vit(model, loader, epochs=5, lr=1e-4, weight_decay=1e-4, class_weights=None):
    """Training optimized for Vision Transformer"""
    model = model.to(device)
    model.train()
    start_time = time.time()

    # Separate parameters for different learning rates
    vit_params = [p for n, p in model.named_parameters() if 'vit' in n]
    classifier_params = [p for n, p in model.named_parameters() if 'classifier' in n]

    optimizer = optim.AdamW([
        {'params': vit_params, 'lr': lr * 0.1},  # Lower LR for pretrained ViT
        {'params': classifier_params, 'lr': lr}   # Higher LR for classifier
    ], weight_decay=weight_decay)

    base_criterion = FocalLoss(alpha=class_weights.to(device) if class_weights is not None else None, gamma=2.0)
    criterion = MOELoss(base_criterion, 0.01 if hasattr(model, 'is_moe') and model.is_moe else 0.0)

    # Cosine annealing scheduler
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=lr*0.01)

    total_loss = 0
    total_samples = 0

    for epoch in range(epochs):
        for X, y in loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            outputs = model(X)
            loss = criterion(outputs, y)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            total_loss += loss.item() * X.size(0)
            total_samples += X.size(0)

        scheduler.step()

    return copy.deepcopy(model.state_dict()), total_loss / total_samples, time.time() - start_time


# ==== Evaluation ====
def eval_model_enhanced(model, loader, class_names):
    model.eval()
    y_true, y_pred, y_prob = [], [], []
    total_loss = 0
    gate_weights_all = []
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)

            if hasattr(model, 'is_moe') and model.is_moe and isinstance(outputs, tuple):
                logits, gate_weights = outputs
                gate_weights_all.append(gate_weights.cpu())
            else:
                logits = outputs

            loss = criterion(logits, y)
            total_loss += loss.item() * X.size(0)
            probs = torch.softmax(logits, dim=1)
            y_true.extend(y.cpu().numpy())
            y_pred.extend(logits.argmax(dim=1).cpu().numpy())
            y_prob.extend(probs.cpu().numpy())

    y_true, y_pred, y_prob = np.array(y_true), np.array(y_pred), np.array(y_prob)
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')

    try:
        y_true_bin = label_binarize(y_true, classes=range(len(class_names)))
        auc_scores = []
        for i in range(len(class_names)):
            if len(np.unique(y_true_bin[:, i])) > 1:
                fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
                auc_scores.append(auc(fpr, tpr))
            else:
                auc_scores.append(0.0)
        auc_roc = np.mean(auc_scores)
    except:
        auc_roc = 0

    results = {
        'accuracy': accuracy,
        'f1': f1,
        'auc_roc': auc_roc,
        'loss': total_loss / len(loader.dataset),
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob
    }

    if gate_weights_all:
        gate_weights_all = torch.cat(gate_weights_all, dim=0)
        expert_usage = gate_weights_all.mean(dim=0).numpy()
        expert_entropy = -np.sum(expert_usage * np.log(expert_usage + 1e-8))
        results['expert_usage'] = expert_usage
        results['expert_entropy'] = expert_entropy

    return results


# ==== Aggregation Methods ====
def fedavg_enhanced(states, weights=None):
    if weights is None:
        weights = [1.0 / len(states)] * len(states)
    avg_state = {}
    for key in states[0].keys():
        if states[0][key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = sum(weights[i] * states[i][key].float() for i in range(len(states)))
        else:
            avg_state[key] = states[0][key].clone()
    return avg_state


def fedprox_aggregation(states, global_state, mu=0.01):
    avg_state = fedavg_enhanced(states)
    for key in avg_state.keys():
        if key in global_state and avg_state[key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = (1 - mu) * avg_state[key] + mu * global_state[key].float()
    return avg_state


def moe_aggregation(local_states, client_weights=None, num_experts=4):
    if client_weights is None:
        client_weights = [1.0 / len(local_states)] * len(local_states)

    shared_state = fedavg_enhanced([
        {k: v for k, v in state.items() if 'classifier' not in k}
        for state in local_states
    ], client_weights)

    expert_states = {}
    for expert_idx in range(num_experts):
        prefix = f'classifier.2.experts.{expert_idx}'
        expert_params = [{k.replace(prefix + '.', ''): v for k, v in state.items() if k.startswith(prefix)} for state in local_states]
        expert_params = [ep for ep in expert_params if ep]
        if expert_params:
            agg_expert = fedavg_enhanced(expert_params, client_weights)
            for k, v in agg_expert.items():
                expert_states[f'{prefix}.{k}'] = v

    gate_params = [{k.replace('classifier.2.gate.', ''): v for k, v in state.items() if k.startswith('classifier.2.gate.')} for state in local_states]
    gate_states = {}
    if gate_params and gate_params[0]:
        agg_gate = fedavg_enhanced(gate_params, client_weights)
        gate_states = {f'classifier.2.gate.{k}': v for k, v in agg_gate.items()}

    other_states = {}
    for state in local_states:
        for k, v in state.items():
            if k.startswith('classifier.') and 'experts' not in k and 'gate' not in k and k not in other_states:
                other_states[k] = []

    for k in other_states.keys():
        values = [state[k] for state in local_states if k in state]
        if values:
            other_states[k] = sum(client_weights[i] * values[i].float() for i in range(len(values)))

    final_state = {**shared_state, **expert_states, **gate_states, **other_states}
    return final_state


# ==== FL Training Loop ====
def run_fl_experiment(mode="fedavg", rounds=25, local_epochs=5, lr=1e-4,
                      client_loaders=None, test_loader=None, class_weights=None,
                      client_indices=None, class_names=None, num_experts=4, model_name='vit_base_patch16_224'):

    use_moe = (mode == "moe")
    model = get_vit_model(
        num_classes=len(class_names),
        model_name=model_name,
        pretrained=True,
        dropout_rate=0.3,
        use_moe=use_moe,
        num_experts=num_experts
    ).to(device)

    comm_tracker = CommCostTracker(model)
    comm_details = comm_tracker.get_detailed_costs()

    print(f"\n{'='*80}")
    print(f"Starting {mode.upper()} Training with Vision Transformer")
    print(f"{'='*80}")
    print(f"Parameters (M): {comm_details['parameters_m']:.2f}")
    print(f"Uplink/Round (MB): {comm_details['uplink_mb']:.2f}")
    print(f"Downlink/Round (MB): {comm_details['downlink_mb']:.2f}")
    print(f"Total Comm./Round (MB): {comm_details['total_comm_mb']:.2f}")

    history = []
    comm_costs = []
    comp_times = []
    client_times = []
    best_f1 = 0
    patience_counter = 0
    best_model_state = None

    for round_num in range(rounds):
        round_start = time.time()
        local_states = []
        round_client_times = []

        for client_id, loader in enumerate(client_loaders):
            client_model = get_vit_model(
                num_classes=len(class_names),
                model_name=model_name,
                pretrained=False,
                dropout_rate=0.3,
                use_moe=use_moe,
                num_experts=num_experts
            ).to(device)
            client_model.load_state_dict(model.state_dict())
            state, loss, client_time = train_local_vit(client_model, loader, epochs=local_epochs, lr=lr, weight_decay=1e-4, class_weights=class_weights)
            local_states.append(state)
            round_client_times.append(client_time)
            del client_model
            gc.collect()
            torch.cuda.empty_cache()

        if mode == "fedavg" or mode == "dp_fedavg":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = fedavg_enhanced(local_states, client_weights)
        elif mode == "fedprox":
            aggregated_state = fedprox_aggregation(local_states, model.state_dict())
        elif mode == "moe":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = moe_aggregation(local_states, client_weights, num_experts)

        model.load_state_dict(aggregated_state)
        eval_results = eval_model_enhanced(model, test_loader, class_names)
        round_time = time.time() - round_start
        avg_client_time = np.mean(round_client_times)

        history.append(eval_results)
        comm_costs.append(comm_details['total_comm_mb'])
        comp_times.append(round_time)
        client_times.append(avg_client_time)

        log_str = (f"Round {round_num + 1:2d} | Acc: {eval_results['accuracy']:.3f} | "
                  f"F1: {eval_results['f1']:.3f} | AUC: {eval_results['auc_roc']:.3f} | "
                  f"Loss: {eval_results['loss']:.3f} | Client: {avg_client_time:.1f}s")
        if 'expert_entropy' in eval_results:
            log_str += f" | Entropy: {eval_results['expert_entropy']:.2f}"
        print(log_str)

        if eval_results['f1'] > best_f1:
            best_f1 = eval_results['f1']
            patience_counter = 0
            best_model_state = copy.deepcopy(model.state_dict())
        else:
            patience_counter += 1
            if patience_counter >= 7:
                print(f"Early stopping at round {round_num + 1}")
                if best_model_state is not None:
                    model.load_state_dict(best_model_state)
                break

    model.comm_details = comm_details
    model.client_times = client_times
    return model, history, comm_costs, comp_times


# ==== Visualization Functions ====
def plot_metrics_comparison(results_dict, class_names):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.ravel()

    metrics = ['accuracy', 'f1', 'auc_roc', 'loss']
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4']

    for i, metric in enumerate(metrics):
        for j, (method, (model, history, _, _)) in enumerate(results_dict.items()):
            values = [r[metric] for r in history]
            axes[i].plot(values, marker='o', label=method.upper(), linewidth=2, color=colors[j])

        axes[i].set_title(f'{metric.replace("_", " ").title()}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel('Round')
        axes[i].set_ylabel(metric.replace("_", " ").title())
        axes[i].legend()
        axes[i].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('vit_metrics_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_roc_curves(best_results, class_names):
    plt.figure(figsize=(12, 8))
    y_true_bin = label_binarize(best_results['y_true'], classes=range(len(class_names)))
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#F39C12']

    for i, (class_name, color) in enumerate(zip(class_names, colors)):
        if len(np.unique(y_true_bin[:, i])) > 1:
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], best_results['y_prob'][:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, color=color, linewidth=2, label=f'{class_name} (AUC = {roc_auc:.3f})')

    plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Multi-class ROC Curves - Vision Transformer', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('vit_roc_curves.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names,
                yticklabels=class_names, cbar_kws={'label': 'Count'})
    plt.title('Confusion Matrix - Vision Transformer', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('vit_confusion_matrix.png', dpi=300, bbox_inches='tight')
    plt.show()


def create_results_table(results_dict):
    fig, ax = plt.subplots(figsize=(18, 6))
    ax.axis('tight')
    ax.axis('off')

    headers = ['Method', 'Accuracy', 'F1-Score', 'AUC-ROC', 'Expert Entropy',
               'Parameters (M)', 'Uplink (MB)', 'Downlink (MB)', 'Total Comm (MB)',
               'Avg Client Time (s)', 'Round Time (s)']

    table_data = []
    for method, (model, history, comm_costs, comp_times) in results_dict.items():
        final = history[-1]
        comm = model.comm_details
        row = [
            method.upper(),
            f"{final['accuracy']:.3f}",
            f"{final['f1']:.3f}",
            f"{final['auc_roc']:.3f}",
            f"{final.get('expert_entropy', 0):.2f}",
            f"{comm['parameters_m']:.2f}",
            f"{comm['uplink_mb']:.2f}",
            f"{comm['downlink_mb']:.2f}",
            f"{comm['total_comm_mb']:.2f}",
            f"{np.mean(model.client_times):.1f}",
            f"{np.mean(comp_times):.1f}"
        ]
        table_data.append(row)

    table = ax.table(cellText=table_data, colLabels=headers, loc='center', cellLoc='center')
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2)

    for i in range(len(headers)):
        table[(0, i)].set_facecolor('#4ECDC4')
        table[(0, i)].set_text_props(weight='bold')

    for i in range(1, len(table_data) + 1):
        for j in range(len(headers)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#F0F0F0')

    plt.title('Vision Transformer Federated Learning - Complete Results', fontsize=14, fontweight='bold', pad=20)
    plt.savefig('vit_results_table.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_communication_analysis(results_dict):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    methods = list(results_dict.keys())
    params = [results_dict[m][0].comm_details['parameters_m'] for m in methods]
    uplink = [results_dict[m][0].comm_details['uplink_mb'] for m in methods]
    downlink = [results_dict[m][0].comm_details['downlink_mb'] for m in methods]
    total_comm = [results_dict[m][0].comm_details['total_comm_mb'] for m in methods]
    client_times = [np.mean(results_dict[m][0].client_times) for m in methods]
    round_times = [np.mean(results_dict[m][3]) for m in methods]
    final_f1 = [results_dict[m][1][-1]['f1'] for m in methods]

    axes[0, 0].bar([m.upper() for m in methods], params, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[0, 0].set_title('Model Parameters (M)', fontweight='bold')
    axes[0, 0].set_ylabel('Parameters (Millions)')
    axes[0, 0].tick_params(axis='x', rotation=15)

    x = np.arange(len(methods))
    width = 0.25
    axes[0, 1].bar(x - width, uplink, width, label='Uplink', color='#FF6B6B')
    axes[0, 1].bar(x, downlink, width, label='Downlink', color='#4ECDC4')
    axes[0, 1].bar(x + width, total_comm, width, label='Total', color='#45B7D1')
    axes[0, 1].set_title('Communication Costs per Round (MB)', fontweight='bold')
    axes[0, 1].set_xticks(x)
    axes[0, 1].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[0, 1].legend()

    axes[1, 0].bar(x - width/2, client_times, width, label='Client Time', color='#96CEB4')
    axes[1, 0].bar(x + width/2, round_times, width, label='Round Time', color='#F39C12')
    axes[1, 0].set_title('Training Times (seconds)', fontweight='bold')
    axes[1, 0].set_xticks(x)
    axes[1, 0].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[1, 0].legend()

    efficiency = [f1 / comm if comm > 0 else 0 for f1, comm in zip(final_f1, total_comm)]
    axes[1, 1].bar([m.upper() for m in methods], efficiency, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[1, 1].set_title('Communication Efficiency (F1/MB)', fontweight='bold')
    axes[1, 1].set_ylabel('F1 Score per MB')
    axes[1, 1].tick_params(axis='x', rotation=15)

    plt.tight_layout()
    plt.savefig('vit_communication_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()


# ==== Main Experiment Runner ====
def run_complete_experiment(base_path, model_name='vit_base_patch16_224'):
    print("="*80)
    print("VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT - APTOS DATASET")
    print("="*80)

    print("\nSetting up APTOS dataset from CSV...")
    train_ds, test_ds, class_names, class_weights, num_classes = setup_aptos_dataset_from_csv(base_path)
    test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

    labels = np.array([y for _, y in train_ds.samples])
    client_indices = split_noniid_aptos(labels, n_clients=4, alpha=0.5)

    print("\nClient Data Distribution:")
    for i, idx in enumerate(client_indices):
        client_labels = labels[idx]
        unique, counts = np.unique(client_labels, return_counts=True)
        class_dist = {class_names[u]: c for u, c in zip(unique, counts)}
        print(f"  Client {i+1}: {len(idx)} samples - {class_dist}")

    client_loaders = []
    for idx in client_indices:
        client_labels = labels[idx]
        sample_weights = class_weights[client_labels]
        sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)
        loader = DataLoader(Subset(train_ds, idx), batch_size=16, sampler=sampler, num_workers=2)
        client_loaders.append(loader)

    results = {}
    methods = ['fedavg', 'fedprox', 'moe']

    for method in methods:
        print(f"\n{'='*80}")
        print(f"EXPERIMENT: {method.upper()}")
        print(f"{'='*80}")

        model, history, comm, comp = run_fl_experiment(
            mode=method,
            rounds=25,
            local_epochs=5,
            lr=1e-4,
            client_loaders=client_loaders,
            test_loader=test_loader,
            class_weights=class_weights,
            client_indices=client_indices,
            class_names=class_names,
            num_experts=4,
            model_name=model_name
        )
        results[method] = (model, history, comm, comp)

        final = history[-1]
        print(f"\n{method.upper()} Final Results:")
        print(f"  Accuracy: {final['accuracy']:.3f}")
        print(f"  F1-Score: {final['f1']:.3f}")
        print(f"  AUC-ROC: {final['auc_roc']:.3f}")
        if 'expert_entropy' in final:
            print(f"  Expert Entropy: {final['expert_entropy']:.2f}")

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: DP-FEDAVG")
    print(f"{'='*80}")

    model_dp, history_dp, comm_dp, comp_dp = run_fl_experiment(
        mode='dp_fedavg',
        rounds=25,
        local_epochs=5,
        lr=1e-4,
        client_loaders=client_loaders,
        test_loader=test_loader,
        class_weights=class_weights,
        client_indices=client_indices,
        class_names=class_names,
        model_name=model_name
    )
    results['dp_fedavg'] = (model_dp, history_dp, comm_dp, comp_dp)

    print(f"\n{'='*80}")
    print("GENERATING VISUALIZATIONS AND ANALYSIS")
    print(f"{'='*80}")

    print("\n1. Plotting metrics comparison...")
    plot_metrics_comparison(results, class_names)

    print("2. Creating results table...")
    create_results_table(results)

    print("3. Plotting communication analysis...")
    plot_communication_analysis(results)

    best_method = max(results.keys(), key=lambda x: results[x][1][-1]['f1'])
    best_model, best_history = results[best_method][:2]
    best_results = best_history[-1]

    print(f"\n{'='*80}")
    print(f"BEST PERFORMING METHOD: {best_method.upper()}")
    print(f"{'='*80}")
    print(f"\nFinal Performance Metrics:")
    print(f"  Accuracy:  {best_results['accuracy']:.3f}")
    print(f"  F1-Score:  {best_results['f1']:.3f}")
    print(f"  AUC-ROC:   {best_results['auc_roc']:.3f}")
    print(f"  Loss:      {best_results['loss']:.3f}")
    if 'expert_entropy' in best_results:
        print(f"  Expert Entropy: {best_results['expert_entropy']:.2f}")

    print("\n4. Plotting ROC curves...")
    plot_roc_curves(best_results, class_names)

    print("5. Plotting confusion matrix...")
    plot_confusion_matrix(best_results['y_true'], best_results['y_pred'], class_names)

    print(f"\n{'='*80}")
    print(f"DETAILED CLASSIFICATION REPORT - {best_method.upper()}")
    print(f"{'='*80}")
    print(classification_report(best_results['y_true'], best_results['y_pred'],
                                target_names=class_names, digits=3))

    print(f"\nPer-Class Performance:")
    cm = confusion_matrix(best_results['y_true'], best_results['y_pred'])
    for i, class_name in enumerate(class_names):
        class_acc = cm[i, i] / cm[i].sum() if cm[i].sum() > 0 else 0
        print(f"  {class_name}: {class_acc:.3f} ({cm[i, i]}/{cm[i].sum()})")

    print(f"\n{'='*80}")
    print("COMMUNICATION EFFICIENCY COMPARISON")
    print(f"{'='*80}")
    print(f"\n{'Method':<15} {'Params(M)':<12} {'Comm(MB)':<12} {'F1':<8} {'Efficiency':<12}")
    print("-" * 70)
    for method, (model, history, _, _) in results.items():
        comm = model.comm_details
        f1 = history[-1]['f1']
        eff = f1 / comm['total_comm_mb'] if comm['total_comm_mb'] > 0 else 0
        print(f"{method.upper():<15} {comm['parameters_m']:<12.2f} {comm['total_comm_mb']:<12.2f} {f1:<8.3f} {eff:<12.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETED SUCCESSFULLY!")
    print(f"{'='*80}")
    print("\nGenerated files:")
    print("  - vit_metrics_comparison.png")
    print("  - vit_results_table.png")
    print("  - vit_communication_analysis.png")
    print("  - vit_roc_curves.png")
    print("  - vit_confusion_matrix.png")

    return results, best_model, best_method, class_names


# ==== RUN THE COMPLETE EXPERIMENT ====
if __name__ == "__main__":
    BASE_PATH = "/content/drive/MyDrive/Retinopathy/APTOS_2019"

    print("\n" + "="*80)
    print("STARTING VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT")
    print("="*80)
    print("\nVision Transformer Architecture:")
    print("  • Model: ViT-Base/16 (pretrained on ImageNet-21k)")
    print("  • Patch size: 16x16")
    print("  • Image size: 224x224")
    print("  • Total: ~86M parameters")
    print("\nKey Advantages:")
    print("  • Pure attention-based architecture (no convolutions)")
    print("  • Global context from the start via self-attention")
    print("  • Strong performance on medical imaging tasks")
    print("  • Pretrained on large-scale ImageNet data")
    print("  • Effective transfer learning capabilities")
    print("\nRunning 4 FL methods (FedAvg, FedProx, FL-MOE, DP-FedAvg)...")
    print("With comprehensive metrics and visualizations...\n")

    # You can change to other ViT variants:
    # 'vit_tiny_patch16_224' - ~5M params (faster, less accurate)
    # 'vit_small_patch16_224' - ~22M params (balanced)
    # 'vit_base_patch16_224' - ~86M params (default, best accuracy)
    # 'vit_large_patch16_224' - ~304M params (highest accuracy, slower)

    results, best_model, best_method, class_names = run_complete_experiment(
        BASE_PATH,
        model_name='vit_base_patch16_224'
    )

    print(f"\n{'='*80}")
    print("ALL EXPERIMENTS COMPLETED!")
    print(f"{'='*80}")
    print(f"\nBest method: {best_method.upper()}")
    print("All results saved and visualizations generated.")
# Out:
# ================================================================================
# STARTING VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT
# ================================================================================
#
# Vision Transformer Architecture:
#   • Model: ViT-Base/16 (pretrained on ImageNet-21k)
#   • Patch size: 16x16
#   • Image size: 224x224
#   • Total: ~86M parameters
#
# Key Advantages:
#   • Pure attention-based architecture (no convolutions)
#   • Global context from the start via self-attention
#   • Strong performance on medical imaging tasks
#   • Pretrained on large-scale ImageNet data
#   • Effective transfer learning capabilities
#
# Running 4 FL methods (FedAvg, FedProx, FL-MOE, DP-FedAvg)...
# With comprehensive metrics and visualizations...
#
# ================================================================================
# VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT - APTOS DATASET
# ================================================================================
#
# Setting up APTOS dataset from CSV...
#
# ================================================================================
# Loading APTOS dataset from: /content/drive/MyDrive/Retinopathy/APTOS_2019
# ================================================================================
#
# Loading CSV files...
#   train_1.csv: 2930 records
#   valid.csv found: Using existing validation set
#   test.csv found: Using existing test set
#
# Detected CSV columns: image='id_code', label='diagnosis'
#
# Dataset Statistics:
#   Number of classes: 5
#   Class labels: [0, 1, 2, 3, 4]
#   ⚠ Warning: 1962 training images not found
#   Training samples loaded: 968/2930
#   Validation samples loaded: 366/366
#
# Class Distribution (Training):
#   Class_0: 817 samples (84.4%)
#   Class_1: 33 samples (3.4%)
#   Class_2: 84 samples (8.7%)
#   Class_3: 7 samples (0.7%)
#   Class_4: 27 samples (2.8%)
#
# Class Weights (for balanced training):
#   Class_0: 0.027
#   Class_1: 0.678
#   Class_2: 0.267
#   Class_3: 3.198
#   Class_4: 0.829
#
# ================================================================================
# Dataset Preparation Complete!
# ================================================================================
#   Training samples: 968
#   Test samples: 366
#   Number of classes: 5
#   Class names: ['Class_0', 'Class_1', 'Class_2', 'Class_3', 'Class_4']
# ================================================================================
#
#
# ================================================================================
# Creating Non-IID Client Split
# ================================================================================
#   Number of clients: 4
#   Dirichlet alpha: 0.5
#   Total samples: 968
#
# Client Data Distribution:
#   Client 1: 737 samples - {'Class_0': 683, 'Class_2': 51, 'Class_3': 3}
#   Client 2: 119 samples - {'Class_0': 51, 'Class_1': 29, 'Class_2': 17, 'Class_3': 2, 'Class_4': 20}
#   Client 3: 51 samples - {'Class_0': 39, 'Class_2': 7, 'Class_3': 1, 'Class_4': 4}
#   Client 4: 61 samples - {'Class_0': 44, 'Class_1': 4, 'Class_2': 9, 'Class_3': 1, 'Class_4': 3}
#
# ================================================================================
# EXPERIMENT: FEDAVG
# ================================================================================
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
#
# ================================================================================
# Starting FEDAVG Training with Vision Transformer
# ================================================================================
# Parameters (M): 86.10
# Uplink/Round (MB): 328.44
# Downlink/Round (MB): 328.44
# Total Comm./Round (MB): 656.88
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  1 | Acc: 0.689 | F1: 0.617 | AUC: 0.692 | Loss: 1.408 | Client: 112.7s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  2 | Acc: 0.727 | F1: 0.645 | AUC: 0.767 | Loss: 1.262 | Client: 41.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  3 | Acc: 0.735 | F1: 0.643 | AUC: 0.735 | Loss: 1.291 | Client: 33.8s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  4 | Acc: 0.738 | F1: 0.652 | AUC: 0.790 | Loss: 1.295 | Client: 32.2s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  5 | Acc: 0.738 | F1: 0.657 | AUC: 0.752 | Loss: 1.470 | Client: 32.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  6 | Acc: 0.740 | F1: 0.652 | AUC: 0.745 | Loss: 1.638 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  7 | Acc: 0.743 | F1: 0.654 | AUC: 0.685 | Loss: 1.927 | Client: 31.4s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  8 | Acc: 0.740 | F1: 0.650 | AUC: 0.680 | Loss: 1.869 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  9 | Acc: 0.743 | F1: 0.654 | AUC: 0.730 | Loss: 1.728 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 10 | Acc: 0.740 | F1: 0.654 | AUC: 0.733 | Loss: 1.684 | Client: 32.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 11 | Acc: 0.743 | F1: 0.652 | AUC: 0.730 | Loss: 1.686 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 12 | Acc: 0.743 | F1: 0.652 | AUC: 0.806 | Loss: 1.428 | Client: 31.1s
# Early stopping at round 12
#
# FEDAVG Final Results:
#   Accuracy: 0.743
#   F1-Score: 0.652
#   AUC-ROC: 0.806
#
# ================================================================================
# EXPERIMENT: FEDPROX
# ================================================================================
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
#
# ================================================================================
# Starting FEDPROX Training with Vision Transformer
# ================================================================================
# Parameters (M): 86.10
# Uplink/Round (MB): 328.44
# Downlink/Round (MB): 328.44
# Total Comm./Round (MB): 656.88
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  1 | Acc: 0.230 | F1: 0.147 | AUC: 0.689 | Loss: 1.892 | Client: 31.9s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  2 | Acc: 0.306 | F1: 0.251 | AUC: 0.764 | Loss: 1.384 | Client: 31.7s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  3 | Acc: 0.464 | F1: 0.455 | AUC: 0.778 | Loss: 1.278 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  4 | Acc: 0.653 | F1: 0.616 | AUC: 0.798 | Loss: 1.074 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  5 | Acc: 0.710 | F1: 0.673 | AUC: 0.811 | Loss: 0.972 | Client: 30.9s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  6 | Acc: 0.730 | F1: 0.677 | AUC: 0.823 | Loss: 0.949 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  7 | Acc: 0.740 | F1: 0.695 | AUC: 0.830 | Loss: 0.897 | Client: 31.2s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  8 | Acc: 0.710 | F1: 0.678 | AUC: 0.810 | Loss: 1.007 | Client: 31.2s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  9 | Acc: 0.749 | F1: 0.708 | AUC: 0.856 | Loss: 0.835 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 10 | Acc: 0.749 | F1: 0.703 | AUC: 0.830 | Loss: 0.908 | Client: 31.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 11 | Acc: 0.738 | F1: 0.702 | AUC: 0.794 | Loss: 1.024 | Client: 31.7s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 12 | Acc: 0.732 | F1: 0.685 | AUC: 0.844 | Loss: 0.911 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 13 | Acc: 0.754 | F1: 0.713 | AUC: 0.818 | Loss: 0.940 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 14 | Acc: 0.746 | F1: 0.677 | AUC: 0.782 | Loss: 1.054 | Client: 31.2s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 15 | Acc: 0.754 | F1: 0.705 | AUC: 0.810 | Loss: 1.004 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 16 | Acc: 0.751 | F1: 0.707 | AUC: 0.805 | Loss: 1.002 | Client: 31.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 17 | Acc: 0.765 | F1: 0.713 | AUC: 0.814 | Loss: 1.002 | Client: 31.7s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 18 | Acc: 0.770 | F1: 0.721 | AUC: 0.788 | Loss: 1.078 | Client: 31.4s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 19 | Acc: 0.732 | F1: 0.694 | AUC: 0.817 | Loss: 1.012 | Client: 31.2s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 20 | Acc: 0.754 | F1: 0.719 | AUC: 0.834 | Loss: 0.935 | Client: 31.4s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 21 | Acc: 0.751 | F1: 0.694 | AUC: 0.809 | Loss: 1.080 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 22 | Acc: 0.746 | F1: 0.714 | AUC: 0.808 | Loss: 0.997 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 23 | Acc: 0.768 | F1: 0.727 | AUC: 0.793 | Loss: 1.037 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 24 | Acc: 0.770 | F1: 0.733 | AUC: 0.816 | Loss: 0.974 | Client: 31.4s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 25 | Acc: 0.751 | F1: 0.691 | AUC: 0.807 | Loss: 1.202 | Client: 31.7s
#
# FEDPROX Final Results:
#   Accuracy: 0.751
#   F1-Score: 0.691
#   AUC-ROC: 0.807
#
# ================================================================================
# EXPERIMENT: MOE
# ================================================================================
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
#
# ================================================================================
# Starting MOE Training with Vision Transformer
# ================================================================================
# Parameters (M): 87.59
# Uplink/Round (MB): 334.11
# Downlink/Round (MB): 334.11
# Total Comm./Round (MB): 668.22
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  1 | Acc: 0.423 | F1: 0.357 | AUC: 0.672 | Loss: 1.451 | Client: 31.5s | Entropy: 1.34
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  2 | Acc: 0.730 | F1: 0.645 | AUC: 0.667 | Loss: 1.292 | Client: 31.3s | Entropy: 1.34
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  3 | Acc: 0.727 | F1: 0.640 | AUC: 0.628 | Loss: 1.337 | Client: 31.5s | Entropy: 1.35
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  4 | Acc: 0.724 | F1: 0.646 | AUC: 0.733 | Loss: 1.111 | Client: 31.8s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  5 | Acc: 0.738 | F1: 0.654 | AUC: 0.756 | Loss: 1.169 | Client: 31.4s | Entropy: 1.36
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  6 | Acc: 0.732 | F1: 0.648 | AUC: 0.758 | Loss: 1.111 | Client: 31.5s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  7 | Acc: 0.735 | F1: 0.648 | AUC: 0.688 | Loss: 1.641 | Client: 31.5s | Entropy: 1.38
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  8 | Acc: 0.735 | F1: 0.651 | AUC: 0.687 | Loss: 1.248 | Client: 32.0s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round  9 | Acc: 0.735 | F1: 0.651 | AUC: 0.717 | Loss: 1.340 | Client: 31.6s | Entropy: 1.38
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 10 | Acc: 0.743 | F1: 0.657 | AUC: 0.772 | Loss: 1.353 | Client: 31.7s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 11 | Acc: 0.738 | F1: 0.651 | AUC: 0.735 | Loss: 1.514 | Client: 31.3s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 12 | Acc: 0.738 | F1: 0.648 | AUC: 0.716 | Loss: 1.610 | Client: 31.5s | Entropy: 1.36
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 13 | Acc: 0.740 | F1: 0.651 | AUC: 0.761 | Loss: 1.414 | Client: 32.0s | Entropy: 1.35
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 14 | Acc: 0.735 | F1: 0.646 | AUC: 0.802 | Loss: 1.764 | Client: 31.5s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 15 | Acc: 0.735 | F1: 0.648 | AUC: 0.782 | Loss: 1.538 | Client: 31.5s | Entropy: 1.37
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ...
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# ✓ Created ViT with MOE (4 experts)
#   Model: vit_base_patch16_224
#   Total parameters: 87,585,432
#   Trainable parameters: 87,585,432
#   Parameters (M): 87.59
#   Model size: 334.11 MB
# Round 17 | Acc: 0.740 | F1: 0.654 | AUC: 0.680 | Loss: 1.800 | Client: 31.5s | Entropy: 1.38
# Early stopping at round 17
#
# MOE Final Results:
#   Accuracy: 0.740
#   F1-Score: 0.654
#   AUC-ROC: 0.680
#   Expert Entropy: 1.38
#
# ================================================================================
# EXPERIMENT: DP-FEDAVG
# ================================================================================
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
#
# ================================================================================
# Starting DP_FEDAVG Training with Vision Transformer
# ================================================================================
# Parameters (M): 86.10
# Uplink/Round (MB): 328.44
# Downlink/Round (MB): 328.44
# Total Comm./Round (MB): 656.88
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  1 | Acc: 0.678 | F1: 0.608 | AUC: 0.703 | Loss: 1.456 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  2 | Acc: 0.721 | F1: 0.637 | AUC: 0.773 | Loss: 1.454 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  3 | Acc: 0.738 | F1: 0.650 | AUC: 0.765 | Loss: 1.372 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  4 | Acc: 0.730 | F1: 0.651 | AUC: 0.751 | Loss: 1.494 | Client: 30.9s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  5 | Acc: 0.732 | F1: 0.645 | AUC: 0.740 | Loss: 1.628 | Client: 31.7s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  6 | Acc: 0.740 | F1: 0.651 | AUC: 0.710 | Loss: 1.715 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  7 | Acc: 0.740 | F1: 0.655 | AUC: 0.737 | Loss: 1.483 | Client: 31.5s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  8 | Acc: 0.735 | F1: 0.654 | AUC: 0.694 | Loss: 1.784 | Client: 31.3s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round  9 | Acc: 0.732 | F1: 0.642 | AUC: 0.643 | Loss: 2.000 | Client: 31.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 10 | Acc: 0.738 | F1: 0.652 | AUC: 0.748 | Loss: 1.734 | Client: 31.0s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 11 | Acc: 0.738 | F1: 0.648 | AUC: 0.751 | Loss: 1.714 | Client: 31.4s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 12 | Acc: 0.740 | F1: 0.652 | AUC: 0.743 | Loss: 1.789 | Client: 31.1s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 13 | Acc: 0.738 | F1: 0.652 | AUC: 0.774 | Loss: 1.819 | Client: 31.6s
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# ✓ Created Vision Transformer model
#   Model: vit_base_patch16_224
#   Total parameters: 86,098,181
#   Trainable parameters: 86,098,181
#   Parameters (M): 86.10
#   Model size: 328.44 MB
# Round 14 | Acc: 0.743 | F1: 0.654 | AUC: 0.802 | Loss: 1.571 | Client: 31.8s
# Early stopping at round 14
#
# ================================================================================
# GENERATING VISUALIZATIONS AND ANALYSIS
# ================================================================================
#
# 1. Plotting metrics comparison...
# 2. Creating results table...
# 3. Plotting communication analysis...
# ================================================================================
# BEST PERFORMING METHOD: FEDPROX
# ================================================================================
#
# Final Performance Metrics:
#   Accuracy:  0.751
#   F1-Score:  0.691
#   AUC-ROC:   0.807
#   Loss:      1.202
#
# 4. Plotting ROC curves...
# 5. Plotting confusion matrix...
# ================================================================================
# DETAILED CLASSIFICATION REPORT - FEDPROX
# ================================================================================
#               precision    recall  f1-score   support
#
#      Class_0      0.966     0.977     0.971       172
#      Class_1      0.000     0.000     0.000        40
#      Class_2      0.570     0.904     0.699       104
#      Class_3      0.000     0.000     0.000        22
#      Class_4      0.481     0.464     0.473        28
#
#     accuracy                          0.751       366
#    macro avg      0.403     0.469     0.429       366
# weighted avg      0.652     0.751     0.691       366
#
#
# Per-Class Performance:
#   Class_0: 0.977 (168/172)
#   Class_1: 0.000 (0/40)
#   Class_2: 0.904 (94/104)
#   Class_3: 0.000 (0/22)
#   Class_4: 0.464 (13/28)
#
# ================================================================================
# COMMUNICATION EFFICIENCY COMPARISON
# ================================================================================
#
# Method          Params(M)    Comm(MB)     F1       Efficiency
# ----------------------------------------------------------------------
# FEDAVG          86.10        656.88       0.652    0.0010
# FEDPROX         86.10        656.88       0.691    0.0011
# MOE             87.59        668.22       0.654    0.0010
# DP_FEDAVG       86.10        656.88       0.654    0.0010
#
# ================================================================================
# EXPERIMENT COMPLETED SUCCESSFULLY!
# ================================================================================
#
# Generated files:
#   - vit_metrics_comparison.png
#   - vit_results_table.png
#   - vit_communication_analysis.png
#   - vit_roc_curves.png
#   - vit_confusion_matrix.png
#
# ================================================================================
# ALL EXPERIMENTS COMPLETED!
# ================================================================================
#
# Best method: FEDPROX
# All results saved and visualizations generated.
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# ==== Vision Transformer Architecture ====
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (accuracy_score, f1_score, recall_score,
                            confusion_matrix, classification_report,
                            roc_curve, auc)
from sklearn.preprocessing import label_binarize # Import label_binarize from preprocessing
import os
import time
import copy
import gc
import pandas as pd
from PIL import Image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class VisionTransformer(nn.Module):
    """Vision Transformer model for APTOS classification"""
    def __init__(self, num_classes=4, model_name='vit_base_patch16_224', pretrained=True, dropout_rate=0.3):
        super(VisionTransformer, self).__init__()

        # Load pretrained ViT from timm
        self.vit = timm.create_model(model_name, pretrained=pretrained, num_classes=0)

        # Get feature dimension
        self.feature_dim = self.vit.num_features

        # Enhanced classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(self.feature_dim),
            nn.Dropout(dropout_rate),
            nn.Linear(self.feature_dim, self.feature_dim // 2),
            nn.GELU(),
            nn.LayerNorm(self.feature_dim // 2),
            nn.Dropout(dropout_rate / 2),
            nn.Linear(self.feature_dim // 2, num_classes)
        )

        self.is_moe = False
        self.model_name = model_name
        self._initialize_classifier()

    def _initialize_classifier(self):
        for m in self.classifier.modules():
            if isinstance(m, nn.Linear):
                nn.init.trunc_normal_(m.weight, std=0.02)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        # Extract features from ViT
        features = self.vit(x)

        # Classify
        output = self.classifier(features)

        return output


class VisionTransformerMOE(nn.Module):
    """Vision Transformer with Mixture of Experts"""
    def __init__(self, num_classes=4, model_name='vit_base_patch16_224', pretrained=True,
                 dropout_rate=0.3, num_experts=4):
        super(VisionTransformerMOE, self).__init__()

        # Load pretrained ViT from timm
        self.vit = timm.create_model(model_name, pretrained=pretrained, num_classes=0)

        # Get feature dimension
        self.feature_dim = self.vit.num_features

        # MOE classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(self.feature_dim),
            nn.Dropout(dropout_rate),
            MixtureOfExperts(
                input_dim=self.feature_dim,
                hidden_dim=self.feature_dim // 2,
                output_dim=num_classes,
                num_experts=num_experts,
                dropout_rate=dropout_rate,
                top_k=2
            )
        )

        self.is_moe = True
        self.model_name = model_name

    def forward(self, x):
        # Extract features from ViT
        features = self.vit(x)

        # MOE returns (logits, gate_weights)
        return self.classifier[2](features)


# ==== MOE Components ====
class ExpertNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(ExpertNetwork, self).__init__()
        self.network = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim // 2, output_dim)
        )

    def forward(self, x):
        return self.network(x)


class GatingNetwork(nn.Module):
    def __init__(self, input_dim, num_experts, dropout_rate=0.1):
        super(GatingNetwork, self).__init__()
        self.gate = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, input_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(input_dim // 2, num_experts),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        return self.gate(x)


class MixtureOfExperts(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_experts=4, dropout_rate=0.3, top_k=2):
        super(MixtureOfExperts, self).__init__()
        self.num_experts = num_experts
        self.top_k = top_k
        self.experts = nn.ModuleList([ExpertNetwork(input_dim, hidden_dim, output_dim, dropout_rate) for _ in range(num_experts)])
        self.gate = GatingNetwork(input_dim, num_experts, dropout_rate)

    def forward(self, x):
        gate_weights = self.gate(x)
        top_k_weights, top_k_indices = torch.topk(gate_weights, self.top_k, dim=-1)
        top_k_weights = top_k_weights / top_k_weights.sum(dim=-1, keepdim=True)

        expert_outputs = torch.stack([expert(x) for expert in self.experts], dim=1)
        batch_size, output_dim = x.size(0), expert_outputs.size(-1)
        final_output = torch.zeros(batch_size, output_dim, device=x.device)

        for i in range(self.top_k):
            expert_idx = top_k_indices[:, i]
            expert_weight = top_k_weights[:, i].unsqueeze(-1)
            selected_outputs = expert_outputs[torch.arange(batch_size), expert_idx]
            final_output += expert_weight * selected_outputs

        return final_output, gate_weights


# ==== Loss Functions ====
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        return focal_loss


class MOELoss(nn.Module):
    def __init__(self, base_criterion, load_balance_weight=0.01):
        super(MOELoss, self).__init__()
        self.base_criterion = base_criterion
        self.load_balance_weight = load_balance_weight

    def forward(self, outputs, targets):
        if isinstance(outputs, tuple):
            logits, gate_weights = outputs
            base_loss = self.base_criterion(logits, targets)
        else:
            logits = outputs
            base_loss = self.base_criterion(logits, targets)
            gate_weights = None

        total_loss = base_loss

        if gate_weights is not None and self.load_balance_weight > 0:
            num_experts = gate_weights.size(-1)
            mean_gate_weights = gate_weights.mean(dim=0)
            uniform_target = torch.ones_like(mean_gate_weights) / num_experts
            load_balance_loss = nn.functional.kl_div(torch.log(mean_gate_weights + 1e-8), uniform_target, reduction='batchmean')
            total_loss += self.load_balance_weight * load_balance_loss

        return total_loss


# ==== Dataset Setup - CSV VERSION ====
def setup_aptos_dataset_from_csv(base_path, test_ratio=0.2, random_seed=42):
    """
    Setup APTOS dataset from CSV files and image folders

    Args:
        base_path: Path to folder containing train_images/, val_images/, test_images/,
                   and train_1.csv, valid.csv, test.csv
        test_ratio: Not used (kept for compatibility), we use existing val/test split
        random_seed: Random seed for reproducibility
    """
    np.random.seed(random_seed)
    torch.manual_seed(random_seed)

    print(f"\n{'='*80}")
    print(f"Loading APTOS dataset from: {base_path}")
    print(f"{'='*80}")

    # Define paths
    train_csv_path = os.path.join(base_path, 'train_1.csv')
    val_csv_path = os.path.join(base_path, 'valid.csv')
    test_csv_path = os.path.join(base_path, 'test.csv')

    train_img_dir = os.path.join(base_path, 'train_images')
    val_img_dir = os.path.join(base_path, 'val_images')
    test_img_dir = os.path.join(base_path, 'test_images')

    # Check if files exist
    if not os.path.exists(train_csv_path):
        raise FileNotFoundError(f"train_1.csv not found at {train_csv_path}")
    if not os.path.exists(train_img_dir):
        raise FileNotFoundError(f"train_images folder not found at {train_img_dir}")

    # Load CSV files
    print("\nLoading CSV files...")
    train_df = pd.read_csv(train_csv_path)
    print(f"  train_1.csv: {len(train_df)} records")

    # Use validation set if exists, otherwise split from training
    if os.path.exists(val_csv_path) and os.path.exists(val_img_dir):
        print(f"  valid.csv found: Using existing validation set")
        val_df = pd.read_csv(val_csv_path)
        use_existing_val = True
    else:
        print(f"  valid.csv not found: Will use test set for validation")
        use_existing_val = False

    # Use test set if exists
    if os.path.exists(test_csv_path) and os.path.exists(test_img_dir):
        print(f"  test.csv found: Using existing test set")
        test_df = pd.read_csv(test_csv_path)
        use_existing_test = True
    else:
        print(f"  test.csv not found: Will split from training")
        use_existing_test = False

    # Detect column names
    img_col = 'id_code' if 'id_code' in train_df.columns else ('image_id' if 'image_id' in train_df.columns else train_df.columns[0])
    label_col = 'diagnosis' if 'diagnosis' in train_df.columns else ('level' if 'level' in train_df.columns else train_df.columns[1])

    print(f"\nDetected CSV columns: image='{img_col}', label='{label_col}'")

    # Get number of classes and class names
    all_labels = train_df[label_col].values
    unique_classes = sorted(np.unique(all_labels))
    num_classes = len(unique_classes)
    class_names = [f"Class_{i}" for i in unique_classes]

    print(f"\nDataset Statistics:")
    print(f"  Number of classes: {num_classes}")
    print(f"  Class labels: {unique_classes}")

    # Prepare training samples
    train_samples = []
    missing_count = 0
    for _, row in train_df.iterrows():
        img_name = str(row[img_col])
        # Try different extensions
        for ext in ['.png', '.jpg', '.jpeg']:
            if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                test_name = img_name + ext
            else:
                test_name = img_name
            img_path = os.path.join(train_img_dir, test_name)
            if os.path.exists(img_path):
                train_samples.append((img_path, int(row[label_col])))
                break
        else:
            missing_count += 1

    if missing_count > 0:
        print(f"  ⚠ Warning: {missing_count} training images not found")
    print(f"  Training samples loaded: {len(train_samples)}/{len(train_df)}")

    # Prepare test/validation samples
    test_samples = []

    if use_existing_val:
        missing_count = 0
        for _, row in val_df.iterrows():
            img_name = str(row[img_col])
            for ext in ['.png', '.jpg', '.jpeg']:
                if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                    test_name = img_name + ext
                else:
                    test_name = img_name
                img_path = os.path.join(val_img_dir, test_name)
                if os.path.exists(img_path):
                    test_samples.append((img_path, int(row[label_col])))
                    break
            else:
                missing_count += 1
        if missing_count > 0:
            print(f"  ⚠ Warning: {missing_count} validation images not found")
        print(f"  Validation samples loaded: {len(test_samples)}/{len(val_df)}")

    elif use_existing_test:
        missing_count = 0
        for _, row in test_df.iterrows():
            img_name = str(row[img_col])
            for ext in ['.png', '.jpg', '.jpeg']:
                if not img_name.endswith(('.png', '.jpg', '.jpeg')):
                    test_name = img_name + ext
                else:
                    test_name = img_name
                img_path = os.path.join(test_img_dir, test_name)
                if os.path.exists(img_path):
                    test_samples.append((img_path, int(row[label_col])))
                    break
            else:
                missing_count += 1
        if missing_count > 0:
            print(f"  ⚠ Warning: {missing_count} test images not found")
        print(f"  Test samples loaded: {len(test_samples)}/{len(test_df)}")

    else:
        print(f"\nCreating stratified test split ({test_ratio*100}%)...")
        train_temp = []
        for class_idx in unique_classes:
            class_samples = [(p, l) for p, l in train_samples if l == class_idx]
            np.random.shuffle(class_samples)
            n_test = max(1, int(len(class_samples) * test_ratio))
            test_samples.extend(class_samples[-n_test:])
            train_temp.extend(class_samples[:-n_test])
        train_samples = train_temp
        print(f"  Split complete: {len(train_samples)} train, {len(test_samples)} test")

    # Calculate class distribution and weights
    train_labels = [label for _, label in train_samples]
    class_counts = torch.zeros(num_classes)
    for label in train_labels:
        class_counts[label] += 1

    print(f"\nClass Distribution (Training):")
    for i, count in enumerate(class_counts):
        percentage = (count / len(train_labels)) * 100
        print(f"  {class_names[i]}: {int(count)} samples ({percentage:.1f}%)")

    # Calculate class weights for balanced training
    class_weights = 1.0 / (class_counts + 1e-8)
    class_weights = class_weights / class_weights.sum() * num_classes

    print(f"\nClass Weights (for balanced training):")
    for i, weight in enumerate(class_weights):
        print(f"  {class_names[i]}: {weight:.3f}")

    # Define transforms for ViT (224x224 standard)
    train_tfm = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    test_tfm = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Create dataset class
    class APTOSDataset(Dataset):
        def __init__(self, samples, transform=None):
            self.samples = samples
            self.transform = transform

        def __len__(self):
            return len(self.samples)

        def __getitem__(self, idx):
            from PIL import Image
            img_path, label = self.samples[idx]
            try:
                image = Image.open(img_path).convert('RGB')
                if self.transform:
                    image = self.transform(image)
                return image, label
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")
                # Return a black image in case of error
                if self.transform:
                    return torch.zeros(3, 224, 224), label
                else:
                    return Image.new('RGB', (224, 224)), label

    # Create datasets
    train_ds = APTOSDataset(train_samples, transform=train_tfm)
    test_ds = APTOSDataset(test_samples, transform=test_tfm)

    # Set attributes for compatibility
    train_ds.classes = test_ds.classes = class_names
    train_ds.samples = train_samples
    test_ds.samples = test_samples

    print(f"\n{'='*80}")
    print(f"Dataset Preparation Complete!")
    print(f"{'='*80}")
    print(f"  Training samples: {len(train_ds)}")
    print(f"  Test samples: {len(test_ds)}")
    print(f"  Number of classes: {num_classes}")
    print(f"  Class names: {class_names}")
    print(f"{'='*80}\n")

    return train_ds, test_ds, class_names, class_weights, num_classes


def split_noniid_aptos(labels, n_clients=4, alpha=0.5):
    """Create Non-IID split using Dirichlet distribution"""
    idxs = np.arange(len(labels))
    client_idx = [[] for _ in range(n_clients)]
    unique_classes = np.unique(labels)

    print(f"\n{'='*80}")
    print(f"Creating Non-IID Client Split")
    print(f"{'='*80}")
    print(f"  Number of clients: {n_clients}")
    print(f"  Dirichlet alpha: {alpha}")
    print(f"  Total samples: {len(labels)}")

    for c in unique_classes:
        idx_c = idxs[labels == c]
        np.random.shuffle(idx_c)
        props = np.random.dirichlet([alpha] * n_clients)
        props = props / props.sum()
        splits = (props.cumsum()[:-1] * len(idx_c)).astype(int)
        splits = np.split(idx_c, splits)
        for i in range(n_clients):
            client_idx[i] += splits[i].tolist()

    for i in range(n_clients):
        np.random.shuffle(client_idx[i])

    return client_idx


# ==== Model Creation ====
def get_vit_model(num_classes=4, model_name='vit_base_patch16_224', pretrained=True,
                  dropout_rate=0.3, use_moe=False, num_experts=4):
    """
    Create Vision Transformer model

    Available models:
    - vit_tiny_patch16_224
    - vit_small_patch16_224
    - vit_base_patch16_224
    - vit_base_patch16_384
    - vit_large_patch16_224
    """

    if use_moe:
        model = VisionTransformerMOE(
            num_classes=num_classes,
            model_name=model_name,
            pretrained=pretrained,
            dropout_rate=dropout_rate,
            num_experts=num_experts
        )
        print(f"✓ Created ViT with MOE ({num_experts} experts)")
    else:
        model = VisionTransformer(
            num_classes=num_classes,
            model_name=model_name,
            pretrained=pretrained,
            dropout_rate=dropout_rate
        )
        print("✓ Created Vision Transformer model")

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"  Model: {model_name}")
    print(f"  Total parameters: {total_params:,}")
    print(f"  Trainable parameters: {trainable_params:,}")
    print(f"  Parameters (M): {total_params / 1e6:.2f}")
    print(f"  Model size: {total_params * 4 / (1024**2):.2f} MB")

    return model


# ==== Communication Cost Tracker ====
class CommCostTracker:
    def __init__(self, model):
        self.param_count = sum(p.numel() for p in model.parameters())
        self.param_size_mb = self.param_count * 4 / (1024 ** 2)

    def get_detailed_costs(self):
        return {
            'parameters_m': self.param_count / 1e6,
            'uplink_mb': self.param_size_mb,
            'downlink_mb': self.param_size_mb,
            'total_comm_mb': self.param_size_mb * 2
        }


# ==== Training Function ====
def train_local_vit(model, loader, epochs=5, lr=1e-4, weight_decay=1e-4, class_weights=None):
    """Training optimized for Vision Transformer"""
    model = model.to(device)
    model.train()
    start_time = time.time()

    # Separate parameters for different learning rates
    vit_params = [p for n, p in model.named_parameters() if 'vit' in n]
    classifier_params = [p for n, p in model.named_parameters() if 'classifier' in n]

    optimizer = optim.AdamW([
        {'params': vit_params, 'lr': lr * 0.1},  # Lower LR for pretrained ViT
        {'params': classifier_params, 'lr': lr}   # Higher LR for classifier
    ], weight_decay=weight_decay)

    base_criterion = FocalLoss(alpha=class_weights.to(device) if class_weights is not None else None, gamma=2.0)
    criterion = MOELoss(base_criterion, 0.01 if hasattr(model, 'is_moe') and model.is_moe else 0.0)

    # Cosine annealing scheduler
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=lr*0.01)

    total_loss = 0
    total_samples = 0

    for epoch in range(epochs):
        for X, y in loader:
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()
            outputs = model(X)
            loss = criterion(outputs, y)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            total_loss += loss.item() * X.size(0)
            total_samples += X.size(0)

        scheduler.step()

    return copy.deepcopy(model.state_dict()), total_loss / total_samples, time.time() - start_time


# ==== Evaluation ====
def eval_model_enhanced(model, loader, class_names):
    model.eval()
    y_true, y_pred, y_prob = [], [], []
    total_loss = 0
    gate_weights_all = []
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)

            if hasattr(model, 'is_moe') and model.is_moe and isinstance(outputs, tuple):
                logits, gate_weights = outputs
                gate_weights_all.append(gate_weights.cpu())
            else:
                logits = outputs

            loss = criterion(logits, y)
            total_loss += loss.item() * X.size(0)
            probs = torch.softmax(logits, dim=1)
            y_true.extend(y.cpu().numpy())
            y_pred.extend(logits.argmax(dim=1).cpu().numpy())
            y_prob.extend(probs.cpu().numpy())

    y_true, y_pred, y_prob = np.array(y_true), np.array(y_pred), np.array(y_prob)
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')

    try:
        y_true_bin = label_binarize(y_true, classes=range(len(class_names)))
        auc_scores = []
        for i in range(len(class_names)):
            if len(np.unique(y_true_bin[:, i])) > 1:
                fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
                auc_scores.append(auc(fpr, tpr))
            else:
                auc_scores.append(0.0)
        auc_roc = np.mean(auc_scores)
    except:
        auc_roc = 0

    results = {
        'accuracy': accuracy,
        'f1': f1,
        'auc_roc': auc_roc,
        'loss': total_loss / len(loader.dataset),
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob
    }

    if gate_weights_all:
        gate_weights_all = torch.cat(gate_weights_all, dim=0)
        expert_usage = gate_weights_all.mean(dim=0).numpy()
        expert_entropy = -np.sum(expert_usage * np.log(expert_usage + 1e-8))
        results['expert_usage'] = expert_usage
        results['expert_entropy'] = expert_entropy

    return results


# ==== Aggregation Methods ====
def fedavg_enhanced(states, weights=None):
    if weights is None:
        weights = [1.0 / len(states)] * len(states)
    avg_state = {}
    for key in states[0].keys():
        if states[0][key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = sum(weights[i] * states[i][key].float() for i in range(len(states)))
        else:
            avg_state[key] = states[0][key].clone()
    return avg_state


def fedprox_aggregation(states, global_state, mu=0.01):
    avg_state = fedavg_enhanced(states)
    for key in avg_state.keys():
        if key in global_state and avg_state[key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = (1 - mu) * avg_state[key] + mu * global_state[key].float()
    return avg_state


def moe_aggregation(local_states, client_weights=None, num_experts=4):
    if client_weights is None:
        client_weights = [1.0 / len(local_states)] * len(local_states)

    shared_state = fedavg_enhanced([
        {k: v for k, v in state.items() if 'classifier' not in k}
        for state in local_states
    ], client_weights)

    expert_states = {}
    for expert_idx in range(num_experts):
        prefix = f'classifier.2.experts.{expert_idx}'
        expert_params = [{k.replace(prefix + '.', ''): v for k, v in state.items() if k.startswith(prefix)} for state in local_states]
        expert_params = [ep for ep in expert_params if ep]
        if expert_params:
            agg_expert = fedavg_enhanced(expert_params, client_weights)
            for k, v in agg_expert.items():
                expert_states[f'{prefix}.{k}'] = v

    gate_params = [{k.replace('classifier.2.gate.', ''): v for k, v in state.items() if k.startswith('classifier.2.gate.')} for state in local_states]
    gate_states = {}
    if gate_params and gate_params[0]:
        agg_gate = fedavg_enhanced(gate_params, client_weights)
        gate_states = {f'classifier.2.gate.{k}': v for k, v in agg_gate.items()}

    other_states = {}
    for state in local_states:
        for k, v in state.items():
            if k.startswith('classifier.') and 'experts' not in k and 'gate' not in k and k not in other_states:
                other_states[k] = []

    for k in other_states.keys():
        values = [state[k] for state in local_states if k in state]
        if values:
            other_states[k] = sum(client_weights[i] * values[i].float() for i in range(len(values)))

    final_state = {**shared_state, **expert_states, **gate_states, **other_states}
    return final_state


# ==== FL Training Loop ====
def run_fl_experiment(mode="fedavg", rounds=25, local_epochs=5, lr=1e-4,
                      client_loaders=None, test_loader=None, class_weights=None,
                      client_indices=None, class_names=None, num_experts=4, model_name='vit_base_patch16_224'):

    use_moe = (mode == "moe")
    model = get_vit_model(
        num_classes=len(class_names),
        model_name=model_name,
        pretrained=True,
        dropout_rate=0.3,
        use_moe=use_moe,
        num_experts=num_experts
    ).to(device)

    comm_tracker = CommCostTracker(model)
    comm_details = comm_tracker.get_detailed_costs()

    print(f"\n{'='*80}")
    print(f"Starting {mode.upper()} Training with Vision Transformer")
    print(f"{'='*80}")
    print(f"Parameters (M): {comm_details['parameters_m']:.2f}")
    print(f"Uplink/Round (MB): {comm_details['uplink_mb']:.2f}")
    print(f"Downlink/Round (MB): {comm_details['downlink_mb']:.2f}")
    print(f"Total Comm./Round (MB): {comm_details['total_comm_mb']:.2f}")

    history = []
    comm_costs = []
    comp_times = []
    client_times = []
    best_f1 = 0
    patience_counter = 0
    best_model_state = None

    for round_num in range(rounds):
        round_start = time.time()
        local_states = []
        round_client_times = []

        for client_id, loader in enumerate(client_loaders):
            client_model = get_vit_model(
                num_classes=len(class_names),
                model_name=model_name,
                pretrained=False,
                dropout_rate=0.3,
                use_moe=use_moe,
                num_experts=num_experts
            ).to(device)
            client_model.load_state_dict(model.state_dict())
            state, loss, client_time = train_local_vit(client_model, loader, epochs=local_epochs, lr=lr, weight_decay=1e-4, class_weights=class_weights)
            local_states.append(state)
            round_client_times.append(client_time)
            del client_model
            gc.collect()
            torch.cuda.empty_cache()

        if mode == "fedavg" or mode == "dp_fedavg":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = fedavg_enhanced(local_states, client_weights)
        elif mode == "fedprox":
            aggregated_state = fedprox_aggregation(local_states, model.state_dict())
        elif mode == "moe":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = moe_aggregation(local_states, client_weights, num_experts)

        model.load_state_dict(aggregated_state)
        eval_results = eval_model_enhanced(model, test_loader, class_names)
        round_time = time.time() - round_start
        avg_client_time = np.mean(round_client_times)

        history.append(eval_results)
        comm_costs.append(comm_details['total_comm_mb'])
        comp_times.append(round_time)
        client_times.append(avg_client_time)

        log_str = (f"Round {round_num + 1:2d} | Acc: {eval_results['accuracy']:.3f} | "
                  f"F1: {eval_results['f1']:.3f} | AUC: {eval_results['auc_roc']:.3f} | "
                  f"Loss: {eval_results['loss']:.3f} | Client: {avg_client_time:.1f}s")
        if 'expert_entropy' in eval_results:
            log_str += f" | Entropy: {eval_results['expert_entropy']:.2f}"
        print(log_str)

        if eval_results['f1'] > best_f1:
            best_f1 = eval_results['f1']
            patience_counter = 0
            best_model_state = copy.deepcopy(model.state_dict())
        else:
            patience_counter += 1
            if patience_counter >= 7:
                print(f"Early stopping at round {round_num + 1}")
                if best_model_state is not None:
                    model.load_state_dict(best_model_state)
                break

    model.comm_details = comm_details
    model.client_times = client_times
    return model, history, comm_costs, comp_times


# ==== Visualization Functions ====
def plot_metrics_comparison(results_dict, class_names):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.ravel()

    metrics = ['accuracy', 'f1', 'auc_roc', 'loss']
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4']

    for i, metric in enumerate(metrics):
        for j, (method, (model, history, _, _)) in enumerate(results_dict.items()):
            values = [r[metric] for r in history]
            axes[i].plot(values, marker='o', label=method.upper(), linewidth=2, color=colors[j])

        axes[i].set_title(f'{metric.replace("_", " ").title()}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel('Round')
        axes[i].set_ylabel(metric.replace("_", " ").title())
        axes[i].legend()
        axes[i].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('vit_metrics_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_roc_curves(best_results, class_names):
    plt.figure(figsize=(12, 8))
    y_true_bin = label_binarize(best_results['y_true'], classes=range(len(class_names)))
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#F39C12']

    for i, (class_name, color) in enumerate(zip(class_names, colors)):
        if len(np.unique(y_true_bin[:, i])) > 1:
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], best_results['y_prob'][:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, color=color, linewidth=2, label=f'{class_name} (AUC = {roc_auc:.3f})')

    plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Multi-class ROC Curves - Vision Transformer', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('vit_roc_curves.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names,
                yticklabels=class_names, cbar_kws={'label': 'Count'})
    plt.title('Confusion Matrix - Vision Transformer', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('vit_confusion_matrix.png', dpi=300, bbox_inches='tight')
    plt.show()


def create_results_table(results_dict):
    fig, ax = plt.subplots(figsize=(18, 6))
    ax.axis('tight')
    ax.axis('off')

    headers = ['Method', 'Accuracy', 'F1-Score', 'AUC-ROC', 'Expert Entropy',
               'Parameters (M)', 'Uplink (MB)', 'Downlink (MB)', 'Total Comm (MB)',
               'Avg Client Time (s)', 'Round Time (s)']

    table_data = []
    for method, (model, history, comm_costs, comp_times) in results_dict.items():
        final = history[-1]
        comm = model.comm_details
        row = [
            method.upper(),
            f"{final['accuracy']:.3f}",
            f"{final['f1']:.3f}",
            f"{final['auc_roc']:.3f}",
            f"{final.get('expert_entropy', 0):.2f}",
            f"{comm['parameters_m']:.2f}",
            f"{comm['uplink_mb']:.2f}",
            f"{comm['downlink_mb']:.2f}",
            f"{comm['total_comm_mb']:.2f}",
            f"{np.mean(model.client_times):.1f}",
            f"{np.mean(comp_times):.1f}"
        ]
        table_data.append(row)

    table = ax.table(cellText=table_data, colLabels=headers, loc='center', cellLoc='center')
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2)

    for i in range(len(headers)):
        table[(0, i)].set_facecolor('#4ECDC4')
        table[(0, i)].set_text_props(weight='bold')

    for i in range(1, len(table_data) + 1):
        for j in range(len(headers)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#F0F0F0')

    plt.title('Vision Transformer Federated Learning - Complete Results', fontsize=14, fontweight='bold', pad=20)
    plt.savefig('vit_results_table.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_communication_analysis(results_dict):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    methods = list(results_dict.keys())
    params = [results_dict[m][0].comm_details['parameters_m'] for m in methods]
    uplink = [results_dict[m][0].comm_details['uplink_mb'] for m in methods]
    downlink = [results_dict[m][0].comm_details['downlink_mb'] for m in methods]
    total_comm = [results_dict[m][0].comm_details['total_comm_mb'] for m in methods]
    client_times = [np.mean(results_dict[m][0].client_times) for m in methods]
    round_times = [np.mean(results[m][3]) for m in methods]
    final_f1 = [results_dict[m][1][-1]['f1'] for m in methods]

    axes[0, 0].bar([m.upper() for m in methods], params, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[0, 0].set_title('Model Parameters (M)', fontweight='bold')
    axes[0, 0].set_ylabel('Parameters (Millions)')
    axes[0, 0].tick_params(axis='x', rotation=15)

    x = np.arange(len(methods))
    width = 0.25
    axes[0, 1].bar(x - width, uplink, width, label='Uplink', color='#FF6B6B')
    axes[0, 1].bar(x, downlink, width, label='Downlink', color='#4ECDC4')
    axes[0, 1].bar(x + width, total_comm, width, label='Total', color='#45B7D1')
    axes[0, 1].set_title('Communication Costs per Round (MB)', fontweight='bold')
    axes[0, 1].set_xticks(x)
    axes[0, 1].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[0, 1].legend()

    axes[1, 0].bar(x - width/2, client_times, width, label='Client Time', color='#96CEB4')
    axes[1, 0].bar(x + width/2, round_times, width, label='Round Time', color='#F39C12')
    axes[1, 0].set_title('Training Times (seconds)', fontweight='bold')
    axes[1, 0].set_xticks(x)
    axes[1, 0].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[1, 0].legend()

    efficiency = [f1 / comm if comm > 0 else 0 for f1, comm in zip(final_f1, total_comm)]
    axes[1, 1].bar([m.upper() for m in methods], efficiency, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[1, 1].set_title('Communication Efficiency (F1/MB)', fontweight='bold')
    axes[1, 1].set_ylabel('F1 Score per MB')
    axes[1, 1].tick_params(axis='x', rotation=15)

    plt.tight_layout()
    plt.savefig('vit_communication_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()


# ==== Main Experiment Runner ====
def run_complete_experiment(base_path, model_name='vit_base_patch16_224'):
    print("="*80)
    print("VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT - APTOS DATASET")
    print("="*80)

    print("\nSetting up APTOS dataset from CSV...")
    train_ds, test_ds, class_names, class_weights, num_classes = setup_aptos_dataset_from_csv(base_path)
    test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

    labels = np.array([y for _, y in train_ds.samples])
    client_indices = split_noniid_aptos(labels, n_clients=4, alpha=0.5)

    print("\nClient Data Distribution:")
    for i, idx in enumerate(client_indices):
        client_labels = labels[idx]
        unique, counts = np.unique(client_labels, return_counts=True)
        class_dist = {class_names[u]: c for u, c in zip(unique, counts)}
        print(f"  Client {i+1}: {len(idx)} samples - {class_dist}")

    client_loaders = []
    for idx in client_indices:
        client_labels = labels[idx]
        sample_weights = class_weights[client_labels]
        sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)
        loader = DataLoader(Subset(train_ds, idx), batch_size=16, sampler=sampler, num_workers=2)
        client_loaders.append(loader)

    results = {}
    methods = ['fedavg', 'fedprox', 'moe']

    for method in methods:
        print(f"\n{'='*80}")
        print(f"EXPERIMENT: {method.upper()}")
        print(f"{'='*80}")

        model, history, comm, comp = run_fl_experiment(
            mode=method,
            rounds=25,
            local_epochs=5,
            lr=1e-4,
            client_loaders=client_loaders,
            test_loader=test_loader,
            class_weights=class_weights,
            client_indices=client_indices,
            class_names=class_names,
            num_experts=4,
            model_name=model_name
        )
        results[method] = (model, history, comm, comp)

        final = history[-1]
        print(f"\n{method.upper()} Final Results:")
        print(f"  Accuracy: {final['accuracy']:.3f}")
        print(f"  F1-Score: {final['f1']:.3f}")
        print(f"  AUC-ROC: {final['auc_roc']:.3f}")
        if 'expert_entropy' in final:
            print(f"  Expert Entropy: {final['expert_entropy']:.2f}")

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: DP-FEDAVG")
    print(f"{'='*80}")

    model_dp, history_dp, comm_dp, comp_dp = run_fl_experiment(
        mode='dp_fedavg',
        rounds=25,
        local_epochs=5,
        lr=1e-4,
        client_loaders=client_loaders,
        test_loader=test_loader,
        class_weights=class_weights,
        client_indices=client_indices,
        class_names=class_names,
        model_name=model_name
    )
    results['dp_fedavg'] = (model_dp, history_dp, comm_dp, comp_dp)

    print(f"\n{'='*80}")
    print("GENERATING VISUALIZATIONS AND ANALYSIS")
    print(f"{'='*80}")

    print("\n1. Plotting metrics comparison...")
    plot_metrics_comparison(results, class_names)

    print("2. Creating results table...")
    create_results_table(results)

    print("3. Plotting communication analysis...")
    plot_communication_analysis(results)

    best_method = max(results.keys(), key=lambda x: results[x][1][-1]['f1'])
    best_model, best_history = results[best_method][:2]
    best_results = best_history[-1]

    print(f"\n{'='*80}")
    print(f"BEST PERFORMING METHOD: {best_method.upper()}")
    print(f"{'='*80}")
    print(f"\nFinal Performance Metrics:")
    print(f"  Accuracy:  {best_results['accuracy']:.3f}")
    print(f"  F1-Score:  {best_results['f1']:.3f}")
    print(f"  AUC-ROC:   {best_results['auc_roc']:.3f}")
    if 'expert_entropy' in best_results:
        print(f"  Expert Entropy: {best_results['expert_entropy']:.2f}")

    print("\n4. Plotting ROC curves...")
    plot_roc_curves(best_results, class_names)

    print("5. Plotting confusion matrix...")
    plot_confusion_matrix(best_results['y_true'], best_results['y_pred'], class_names)

    print(f"\n{'='*80}")
    print(f"DETAILED CLASSIFICATION REPORT - {best_method.upper()}")
    print(f"{'='*80}")
    print(classification_report(best_results['y_true'], best_results['y_pred'],
                                target_names=class_names, digits=3))

    print(f"\nPer-Class Performance:")
    cm = confusion_matrix(best_results['y_true'], best_results['y_pred'])
    for i, class_name in enumerate(class_names):
        class_acc = cm[i, i] / cm[i].sum() if cm[i].sum() > 0 else 0
        print(f"  {class_name}: {class_acc:.3f} ({cm[i, i]}/{cm[i].sum()})")

    print(f"\n{'='*80}")
    print("COMMUNICATION EFFICIENCY COMPARISON")
    print(f"{'='*80}")
    print(f"\n{'Method':<15} {'Params(M)':<12} {'Comm(MB)':<12} {'F1':<8} {'Efficiency':<12}")
    print("-" * 70)
    for method, (model, history, _, _) in results.items():
        comm = model.comm_details
        f1 = history[-1]['f1']
        eff = f1 / comm['total_comm_mb'] if comm['total_comm_mb'] > 0 else 0
        print(f"{method.upper():<15} {comm['parameters_m']:<12.2f} {comm['total_comm_mb']:<12.2f} {f1:<8.3f} {eff:<12.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETED SUCCESSFULLY!")
    print(f"{'='*80}")
    print("\nGenerated files:")
    print("  - vit_metrics_comparison.png")
    print("  - vit_results_table.png")
    print("  - vit_communication_analysis.png")
    print("  - vit_roc_curves.png")
    print("  - vit_confusion_matrix.png")

    return results, best_model, best_method, class_names


# ==== RUN THE COMPLETE EXPERIMENT ====
if __name__ == "__main__":
    BASE_PATH = "/content/drive/MyDrive/Tanjum/Retinopathy/Code/Retino/APTOS/APTOS_2019"

    print("\n" + "="*80)
    print("STARTING VISION TRANSFORMER FEDERATED LEARNING EXPERIMENT")
    print("="*80)
    print("\nVision Transformer Architecture:")
    print("  • Model: ViT-Base/16 (pretrained on ImageNet-21k)")
    print("  • Patch size: 16x16")
    print("  • Image size: 224x224")
    print("  • Total: ~86M parameters")
    print("\nKey Advantages:")
    print("  • Pure attention-based architecture (no convolutions)")
    print("  • Global context from the start via self-attention")
    print("  • Strong performance on medical imaging tasks")
    print("  • Pretrained on large-scale ImageNet data")
    print("  • Effective transfer learning capabilities")
    print("\nRunning 4 FL methods (FedAvg, FedProx, FL-MOE, DP-FedAvg)...")
    print("With comprehensive metrics and visualizations...\n")

    # You can change to other ViT variants:
    # 'vit_tiny_patch16_224' - ~5M params (faster, less accurate)
    # 'vit_small_patch16_224' - ~22M params (balanced)
    # 'vit_base_patch16_224' - ~86M params (default, best accuracy)
    # 'vit_large_patch16_224' - ~304M params (highest accuracy, slower)

    results, best_model, best_method, class_names = run_complete_experiment(
        BASE_PATH,
        model_name='vit_base_patch16_224'
    )

    print(f"\n{'='*80}")
    print("ALL EXPERIMENTS COMPLETED!")
    print(f"{'='*80}")
    print(f"\nBest method: {best_method.upper()}")
    print("All results saved and visualizations generated.")
