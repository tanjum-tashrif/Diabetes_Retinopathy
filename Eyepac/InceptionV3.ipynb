# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install --upgrade --force-reinstall numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.9 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 119.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# Successfully installed numpy-2.3.3

# %%
pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 118.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
pip install --upgrade --force-reinstall torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting setuptools (from torch)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch)
#   Downloading triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl (887.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.9/887.9 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 97.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 24.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 63.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 35.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 57.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.7 MB/s eta 0:00:00
# Downloading triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 13.8 MB/s eta 0:00:00
# Downloading torchvision-0.23.0-cp312-cp312-manylinux_2_28_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 108.1 MB/s eta 0:00:00
# Downloading torchaudio-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 86.4 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 116.2 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.1 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 88.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.9 MB/s eta 0:00:00
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 16.6 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 14.1 MB/s eta 0:00:00
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 53.5 MB/s eta 0:00:00
# Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 34.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, setuptools, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.11.1.6
#     Uninstalling nvidia-cufile-cu12-1.11.1.6:
#       Successfully uninstalled nvidia-cufile-cu12-1.11.1.6
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.19.1
#     Uninstalling filelock-3.19.1:
#       Successfully uninstalled filelock-3.19.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0+cu126
#     Uninstalling torchvision-0.23.0+cu126:
#       Successfully uninstalled torchvision-0.23.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.8.0+cu126
#     Uninstalling torchaudio-2.8.0+cu126:
#       Successfully uninstalled torchaudio-2.8.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-3.19.1 fsspec-2025.9.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.3 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 pillow-11.3.0 setuptools-80.9.0 sympy-1.14.0 torch-2.8.0 torchaudio-2.8.0 torchvision-0.23.0 triton-3.4.0 typing-extensions-4.15.0

# %%
pip install torchcam
# Out:
# Collecting torchcam
#   Downloading torchcam-0.4.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (2.8.0)
# Collecting numpy<2.0.0,>=1.17.2 (from torchcam)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: Pillow!=9.2.0,>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (11.3.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from torchcam) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.7.0->torchcam) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->torchcam) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.0->torchcam) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->torchcam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->torchcam) (3.0.3)
# Downloading torchcam-0.4.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy, torchcam
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 torchcam-0.4.0

# %%
# !pip install torchcam timm --quiet

# %%
import os, time, copy, gc
import numpy as np, matplotlib.pyplot as plt, seaborn as sns
import torch, torch.nn as nn, torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix, roc_curve, precision_recall_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from torchcam.methods import SmoothGradCAMpp
from torchcam.utils import overlay_mask
import warnings
warnings.filterwarnings('ignore')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import os, time, copy, gc
import numpy as np, matplotlib.pyplot as plt, seaborn as sns
import torch, torch.nn as nn, torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix, roc_curve, precision_recall_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from torchcam.methods import SmoothGradCAMpp
from torchcam.utils import overlay_mask
import warnings
warnings.filterwarnings('ignore')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Complete APTOS Federated Learning with InceptionV3
# Generates: Accuracy, F1, AUC, Time, Expert Entropy, Parameters, Communication Costs, ROC, Confusion Matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, WeightedRandomSampler
from torchvision import transforms, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (accuracy_score, f1_score, recall_score,
                            confusion_matrix, classification_report,
                            roc_curve, auc)
from sklearn.preprocessing import label_binarize # Import label_binarize from preprocessing
import os
import time
import copy
import gc

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# ==== MOE Components ====
class ExpertNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(ExpertNetwork, self).__init__()
        self.network = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim // 2, output_dim)
        )

    def forward(self, x):
        return self.network(x)


class GatingNetwork(nn.Module):
    def __init__(self, input_dim, num_experts, dropout_rate=0.1):
        super(GatingNetwork, self).__init__()
        self.gate = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, input_dim // 2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(input_dim // 2, num_experts),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        return self.gate(x)


class MixtureOfExperts(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_experts=4, dropout_rate=0.3, top_k=2):
        super(MixtureOfExperts, self).__init__()
        self.num_experts = num_experts
        self.top_k = top_k
        self.experts = nn.ModuleList([ExpertNetwork(input_dim, hidden_dim, output_dim, dropout_rate) for _ in range(num_experts)])
        self.gate = GatingNetwork(input_dim, num_experts, dropout_rate)

    def forward(self, x):
        gate_weights = self.gate(x)
        top_k_weights, top_k_indices = torch.topk(gate_weights, self.top_k, dim=-1)
        top_k_weights = top_k_weights / top_k_weights.sum(dim=-1, keepdim=True)

        expert_outputs = torch.stack([expert(x) for expert in self.experts], dim=1)
        batch_size, output_dim = x.size(0), expert_outputs.size(-1)
        final_output = torch.zeros(batch_size, output_dim, device=x.device)

        for i in range(self.top_k):
            expert_idx = top_k_indices[:, i]
            expert_weight = top_k_weights[:, i].unsqueeze(-1)
            selected_outputs = expert_outputs[torch.arange(batch_size), expert_idx]
            final_output += expert_weight * selected_outputs

        return final_output, gate_weights


# ==== Loss Functions ====
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        return focal_loss


class MOELoss(nn.Module):
    def __init__(self, base_criterion, load_balance_weight=0.01):
        super(MOELoss, self).__init__()
        self.base_criterion = base_criterion
        self.load_balance_weight = load_balance_weight

    def forward(self, outputs, targets):
        if isinstance(outputs, tuple):
            logits, gate_weights = outputs
            base_loss = self.base_criterion(logits, targets)
        else:
            logits = outputs
            base_loss = self.base_criterion(logits, targets)
            gate_weights = None

        total_loss = base_loss

        if gate_weights is not None and self.load_balance_weight > 0:
            num_experts = gate_weights.size(-1)
            mean_gate_weights = gate_weights.mean(dim=0)
            uniform_target = torch.ones_like(mean_gate_weights) / num_experts
            load_balance_loss = nn.functional.kl_div(torch.log(mean_gate_weights + 1e-8), uniform_target, reduction='batchmean')
            total_loss += self.load_balance_weight * load_balance_loss

        return total_loss


# ==== Dataset Setup ====
def setup_aptos_dataset_with_split(base_path, test_ratio=0.2, random_seed=42):
    np.random.seed(random_seed)
    torch.manual_seed(random_seed)

    # InceptionV3 requires 299x299 input size
    train_tfm = transforms.Compose([
        transforms.Resize((320, 320)),
        transforms.RandomResizedCrop(299, scale=(0.8, 1.0)),  # InceptionV3 uses 299x299
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(20),
        transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    test_tfm = transforms.Compose([
        transforms.Resize((299, 299)),  # InceptionV3 uses 299x299
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    class_folders = sorted([f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))])
    print(f"Found classes: {class_folders}")

    all_samples = []
    class_to_idx = {class_name: idx for idx, class_name in enumerate(class_folders)}

    for class_name in class_folders:
        class_path = os.path.join(base_path, class_name)
        class_idx = class_to_idx[class_name]
        image_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        print(f"Class '{class_name}': {len(image_files)} samples")
        for img_file in image_files:
            all_samples.append((os.path.join(class_path, img_file), class_idx))

    train_samples, test_samples = [], []
    class_counts = torch.zeros(len(class_folders))

    for class_idx, class_name in enumerate(class_folders):
        class_samples = [(path, label) for path, label in all_samples if label == class_idx]
        np.random.shuffle(class_samples)
        n_test = max(1, int(len(class_samples) * test_ratio))
        n_train = len(class_samples) - n_test
        train_samples.extend(class_samples[:n_train])
        test_samples.extend(class_samples[n_train:])
        class_counts[class_idx] = n_train

    np.random.shuffle(train_samples)
    np.random.shuffle(test_samples)

    class APTOSDataset(torch.utils.data.Dataset):
        def __init__(self, samples, transform=None):
            self.samples = samples
            self.transform = transform

        def __len__(self):
            return len(self.samples)

        def __getitem__(self, idx):
            from PIL import Image
            path, label = self.samples[idx]
            image = Image.open(path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            return image, label

    train_ds = APTOSDataset(train_samples, transform=train_tfm)
    test_ds = APTOSDataset(test_samples, transform=test_tfm)
    train_ds.classes = test_ds.classes = class_folders

    class_weights = 1.0 / (class_counts + 1e-8)
    class_weights = class_weights / class_weights.sum() * len(class_folders)

    print(f"\nDataset prepared:")
    print(f"  Training samples: {len(train_ds)}")
    print(f"  Test samples: {len(test_ds)}")

    return train_ds, test_ds, class_folders, class_weights, len(class_folders)


def split_noniid_aptos(labels, n_clients=4, alpha=0.3):
    idxs = np.arange(len(labels))
    client_idx = [[] for _ in range(n_clients)]
    unique_classes = np.unique(labels)

    print(f"\nCreating Non-IID split with alpha={alpha}")
    for c in unique_classes:
        idx_c = idxs[labels == c]
        np.random.shuffle(idx_c)
        props = np.random.dirichlet([alpha] * n_clients)
        props = props / props.sum()
        splits = (props.cumsum()[:-1] * len(idx_c)).astype(int)
        splits = np.split(idx_c, splits)
        for i in range(n_clients):
            client_idx[i] += splits[i].tolist()

    for i in range(n_clients):
        np.random.shuffle(client_idx[i])

    return client_idx


# ==== InceptionV3 Model Creation ====
def get_inceptionv3_model(num_classes=5, pretrained=True, dropout_rate=0.5, use_moe=False, num_experts=4):
    """Create InceptionV3 model for APTOS classification"""

    # Load pretrained InceptionV3
    model = models.inception_v3(pretrained=pretrained, aux_logits=True)

    # Get number of features from final layer
    num_features = model.fc.in_features

    if use_moe:
        # Replace with MOE classifier
        model.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            MixtureOfExperts(
                input_dim=num_features,
                hidden_dim=num_features // 2,
                output_dim=num_classes,
                num_experts=num_experts,
                dropout_rate=dropout_rate,
                top_k=2
            )
        )

        # Also update auxiliary classifier for training
        if model.aux_logits:
            num_aux_features = model.AuxLogits.fc.in_features
            model.AuxLogits.fc = nn.Linear(num_aux_features, num_classes)

        model.is_moe = True
        print(f"Created InceptionV3 with MOE ({num_experts} experts)")
    else:
        # Enhanced classifier with multiple layers
        model.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(num_features, num_features // 2),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(num_features // 2),
            nn.Dropout(dropout_rate),
            nn.Linear(num_features // 2, num_features // 4),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(num_features // 4),
            nn.Dropout(dropout_rate / 2),
            nn.Linear(num_features // 4, num_classes)
        )

        # Update auxiliary classifier
        if model.aux_logits:
            num_aux_features = model.AuxLogits.fc.in_features
            model.AuxLogits.fc = nn.Linear(num_aux_features, num_classes)

        model.is_moe = False
        print("Created InceptionV3 model")

    # Initialize new layers
    for m in model.fc.modules():
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm1d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"Total parameters: {total_params:,}")
    print(f"Trainable parameters: {trainable_params:,}")
    print(f"Parameters (M): {total_params / 1e6:.2f}")
    print(f"Model size: {total_params * 4 / (1024**2):.2f} MB")

    return model


# ==== Communication Cost Tracker ====
class CommCostTracker:
    def __init__(self, model):
        self.param_count = sum(p.numel() for p in model.parameters())
        self.param_size_mb = self.param_count * 4 / (1024 ** 2)

    def get_detailed_costs(self):
        return {
            'parameters_m': self.param_count / 1e6,
            'uplink_mb': self.param_size_mb,
            'downlink_mb': self.param_size_mb,
            'total_comm_mb': self.param_size_mb * 2
        }


# ==== Training Function ====
def train_local_inceptionv3(model, loader, epochs=5, lr=1e-3, weight_decay=1e-4, class_weights=None):
    """Training function optimized for InceptionV3"""
    model = model.to(device)
    model.train()
    start_time = time.time()

    # Different learning rates for backbone and classifier
    backbone_params = []
    classifier_params = []

    for name, param in model.named_parameters():
        if 'fc' in name or 'AuxLogits' in name:
            classifier_params.append(param)
        else:
            backbone_params.append(param)

    # Lower LR for pretrained backbone, higher for new classifier
    optimizer = optim.AdamW([
        {'params': backbone_params, 'lr': lr * 0.1},
        {'params': classifier_params, 'lr': lr}
    ], weight_decay=weight_decay)

    base_criterion = FocalLoss(alpha=class_weights.to(device) if class_weights is not None else None, gamma=2.0)
    criterion = MOELoss(base_criterion, 0.01 if hasattr(model, 'is_moe') and model.is_moe else 0.0)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=lr*0.001)

    total_loss = 0
    total_samples = 0

    for epoch in range(epochs):
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()

            # InceptionV3 returns auxiliary outputs during training
            if model.training and model.aux_logits:
                outputs, aux_outputs = model(X)
                main_loss = criterion(outputs, y)
                aux_loss = nn.functional.cross_entropy(aux_outputs, y)
                loss = main_loss + 0.4 * aux_loss  # Weighted auxiliary loss
            else:
                outputs = model(X)
                loss = criterion(outputs, y)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            total_loss += loss.item() * X.size(0)
            total_samples += X.size(0)
        scheduler.step()

    return copy.deepcopy(model.state_dict()), total_loss / total_samples, time.time() - start_time


# ==== Evaluation ====
def eval_model_enhanced(model, loader, class_names):
    model.eval()
    y_true, y_pred, y_prob = [], [], []
    total_loss = 0
    gate_weights_all = []
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)

            # Handle InceptionV3 outputs (might return tuple during eval too)
            if isinstance(outputs, tuple) and len(outputs) == 2:
                # Check if it's (main_output, aux_output) or (logits, gate_weights)
                if hasattr(model, 'is_moe') and model.is_moe and outputs[1].dim() == 2 and outputs[1].size(1) <= 10:
                    # It's MOE: (logits, gate_weights)
                    logits, gate_weights = outputs
                    gate_weights_all.append(gate_weights.cpu())
                else:
                    # It's InceptionV3: (main_output, aux_output)
                    logits = outputs[0]
            else:
                logits = outputs

            loss = criterion(logits, y)
            total_loss += loss.item() * X.size(0)
            probs = torch.softmax(logits, dim=1)
            y_true.extend(y.cpu().numpy())
            y_pred.extend(logits.argmax(dim=1).cpu().numpy())
            y_prob.extend(probs.cpu().numpy())

    y_true, y_pred, y_prob = np.array(y_true), np.array(y_pred), np.array(y_prob)
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')

    try:
        y_true_bin = label_binarize(y_true, classes=range(len(class_names)))
        auc_scores = []
        for i in range(len(class_names)):
            if len(np.unique(y_true_bin[:, i])) > 1:
                fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
                auc_scores.append(auc(fpr, tpr))
            else:
                auc_scores.append(0.0)
        auc_roc = np.mean(auc_scores)
    except:
        auc_roc = 0

    results = {
        'accuracy': accuracy,
        'f1': f1,
        'auc_roc': auc_roc,
        'loss': total_loss / len(loader.dataset),
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob
    }

    if gate_weights_all:
        gate_weights_all = torch.cat(gate_weights_all, dim=0)
        expert_usage = gate_weights_all.mean(dim=0).numpy()
        expert_entropy = -np.sum(expert_usage * np.log(expert_usage + 1e-8))
        results['expert_usage'] = expert_usage
        results['expert_entropy'] = expert_entropy

    return results


# ==== Aggregation Methods ====
def fedavg_enhanced(states, weights=None):
    if weights is None:
        weights = [1.0 / len(states)] * len(states)
    avg_state = {}
    for key in states[0].keys():
        if states[0][key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = sum(weights[i] * states[i][key].float() for i in range(len(states)))
        else:
            avg_state[key] = states[0][key].clone()
    return avg_state


def fedprox_aggregation(states, global_state, mu=0.01):
    avg_state = fedavg_enhanced(states)
    for key in avg_state.keys():
        if key in global_state and avg_state[key].dtype in [torch.float32, torch.float64, torch.float16]:
            avg_state[key] = (1 - mu) * avg_state[key] + mu * global_state[key].float()
    return avg_state


def moe_aggregation(local_states, client_weights=None, num_experts=4):
    if client_weights is None:
        client_weights = [1.0 / len(local_states)] * len(local_states)

    # Aggregate backbone (everything except fc layer)
    shared_state = fedavg_enhanced([
        {k: v for k, v in state.items() if 'fc' not in k and 'AuxLogits' not in k}
        for state in local_states
    ], client_weights)

    # Aggregate MOE experts
    expert_states = {}
    for expert_idx in range(num_experts):
        prefix = f'fc.1.experts.{expert_idx}'
        expert_params = [{k.replace(prefix + '.', ''): v for k, v in state.items() if k.startswith(prefix)} for state in local_states]
        expert_params = [ep for ep in expert_params if ep]
        if expert_params:
            agg_expert = fedavg_enhanced(expert_params, client_weights)
            for k, v in agg_expert.items():
                expert_states[f'{prefix}.{k}'] = v

    # Aggregate gating network
    gate_params = [{k.replace('fc.1.gate.', ''): v for k, v in state.items() if k.startswith('fc.1.gate.')} for state in local_states]
    gate_states = {}
    if gate_params and gate_params[0]:
        agg_gate = fedavg_enhanced(gate_params, client_weights)
        gate_states = {f'fc.1.gate.{k}': v for k, v in agg_gate.items()}

    # Aggregate auxiliary classifier and other fc components
    other_states = {}
    for state in local_states:
        for k, v in state.items():
            if (k.startswith('fc.') or k.startswith('AuxLogits.')) and 'experts' not in k and 'gate' not in k and k not in other_states:
                other_states[k] = []

    for k in other_states.keys():
        values = [state[k] for state in local_states if k in state]
        if values:
            other_states[k] = sum(client_weights[i] * values[i].float() for i in range(len(values)))

    # Combine all
    final_state = {**shared_state, **expert_states, **gate_states, **other_states}
    return final_state


# ==== FL Training Loop ====
def run_fl_experiment(mode="fedavg", rounds=15, local_epochs=3, lr=1e-3,
                      client_loaders=None, test_loader=None, class_weights=None,
                      client_indices=None, class_names=None, num_experts=4):

    use_moe = (mode == "moe")
    model = get_inceptionv3_model(num_classes=len(class_names), pretrained=True, use_moe=use_moe, num_experts=num_experts).to(device)

    comm_tracker = CommCostTracker(model)
    comm_details = comm_tracker.get_detailed_costs()

    print(f"\n{'='*80}")
    print(f"Starting {mode.upper()} Training with InceptionV3")
    print(f"{'='*80}")
    print(f"Parameters (M): {comm_details['parameters_m']:.2f}")
    print(f"Uplink/Round (MB): {comm_details['uplink_mb']:.2f}")
    print(f"Downlink/Round (MB): {comm_details['downlink_mb']:.2f}")
    print(f"Total Comm./Round (MB): {comm_details['total_comm_mb']:.2f}")

    history = []
    comm_costs = []
    comp_times = []
    client_times = []
    best_f1 = 0
    patience_counter = 0
    best_model_state = None

    for round_num in range(rounds):
        round_start = time.time()
        local_states = []
        round_client_times = []

        for client_id, loader in enumerate(client_loaders):
            client_model = get_inceptionv3_model(num_classes=len(class_names), pretrained=False, use_moe=use_moe, num_experts=num_experts).to(device)
            client_model.load_state_dict(model.state_dict())
            state, loss, client_time = train_local_inceptionv3(client_model, loader, epochs=local_epochs, lr=lr, class_weights=class_weights)
            local_states.append(state)
            round_client_times.append(client_time)
            del client_model
            gc.collect()
            torch.cuda.empty_cache()

        if mode == "fedavg" or mode == "dp_fedavg":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = fedavg_enhanced(local_states, client_weights)
        elif mode == "fedprox":
            aggregated_state = fedprox_aggregation(local_states, model.state_dict())
        elif mode == "moe":
            client_weights = [len(idx) / sum(len(i) for i in client_indices) for idx in client_indices]
            aggregated_state = moe_aggregation(local_states, client_weights, num_experts)

        model.load_state_dict(aggregated_state)
        eval_results = eval_model_enhanced(model, test_loader, class_names)
        round_time = time.time() - round_start
        avg_client_time = np.mean(round_client_times)

        history.append(eval_results)
        comm_costs.append(comm_details['total_comm_mb'])
        comp_times.append(round_time)
        client_times.append(avg_client_time)

        log_str = (f"Round {round_num + 1:2d} | Acc: {eval_results['accuracy']:.3f} | "
                  f"F1: {eval_results['f1']:.3f} | AUC: {eval_results['auc_roc']:.3f} | "
                  f"Loss: {eval_results['loss']:.3f} | Client: {avg_client_time:.1f}s")
        if 'expert_entropy' in eval_results:
            log_str += f" | Entropy: {eval_results['expert_entropy']:.2f}"
        print(log_str)

        # Early stopping
        if eval_results['f1'] > best_f1:
            best_f1 = eval_results['f1']
            patience_counter = 0
            best_model_state = copy.deepcopy(model.state_dict())
        else:
            patience_counter += 1
            if patience_counter >= 5:
                print(f"Early stopping at round {round_num + 1}")
                if best_model_state is not None:
                    model.load_state_dict(best_model_state)
                break

    model.comm_details = comm_details
    model.client_times = client_times
    return model, history, comm_costs, comp_times


# ==== Visualization Functions ====
def plot_metrics_comparison(results_dict, class_names):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.ravel()

    metrics = ['accuracy', 'f1', 'auc_roc', 'loss']
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4']

    for i, metric in enumerate(metrics):
        for j, (method, (model, history, _, _)) in enumerate(results_dict.items()):
            values = [r[metric] for r in history]
            axes[i].plot(values, marker='o', label=method.upper(), linewidth=2, color=colors[j])

        axes[i].set_title(f'{metric.replace("_", " ").title()}', fontsize=12, fontweight='bold')
        axes[i].set_xlabel('Round')
        axes[i].set_ylabel(metric.replace("_", " ").title())
        axes[i].legend()
        axes[i].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('inceptionv3_metrics_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_roc_curves(best_results, class_names):
    plt.figure(figsize=(12, 8))
    y_true_bin = label_binarize(best_results['y_true'], classes=range(len(class_names)))
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#F39C12']

    for i, (class_name, color) in enumerate(zip(class_names, colors)):
        if len(np.unique(y_true_bin[:, i])) > 1:
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], best_results['y_prob'][:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, color=color, linewidth=2, label=f'{class_name} (AUC = {roc_auc:.3f})')

    plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Multi-class ROC Curves - InceptionV3', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('inceptionv3_roc_curves.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names,
                yticklabels=class_names, cbar_kws={'label': 'Count'})
    plt.title('Confusion Matrix - InceptionV3', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('inceptionv3_confusion_matrix.png', dpi=300, bbox_inches='tight')
    plt.show()


def create_results_table(results_dict):
    fig, ax = plt.subplots(figsize=(18, 6))
    ax.axis('tight')
    ax.axis('off')

    headers = ['Method', 'Accuracy', 'F1-Score', 'AUC-ROC', 'Expert Entropy',
               'Parameters (M)', 'Uplink (MB)', 'Downlink (MB)', 'Total Comm (MB)',
               'Avg Client Time (s)', 'Round Time (s)']

    table_data = []
    for method, (model, history, comm_costs, comp_times) in results_dict.items():
        final = history[-1]
        comm = model.comm_details
        row = [
            method.upper(),
            f"{final['accuracy']:.3f}",
            f"{final['f1']:.3f}",
            f"{final['auc_roc']:.3f}",
            f"{final.get('expert_entropy', 0):.2f}",
            f"{comm['parameters_m']:.2f}",
            f"{comm['uplink_mb']:.2f}",
            f"{comm['downlink_mb']:.2f}",
            f"{comm['total_comm_mb']:.2f}",
            f"{np.mean(model.client_times):.1f}",
            f"{np.mean(comp_times):.1f}"
        ]
        table_data.append(row)

    table = ax.table(cellText=table_data, colLabels=headers, loc='center', cellLoc='center')
    table.auto_set_font_size(False)
    table.set_fontsize(9)
    table.scale(1.2, 2)

    for i in range(len(headers)):
        table[(0, i)].set_facecolor('#4ECDC4')
        table[(0, i)].set_text_props(weight='bold')

    for i in range(1, len(table_data) + 1):
        for j in range(len(headers)):
            if i % 2 == 0:
                table[(i, j)].set_facecolor('#F0F0F0')

    plt.title('InceptionV3 Federated Learning - Complete Results', fontsize=14, fontweight='bold', pad=20)
    plt.savefig('inceptionv3_results_table.png', dpi=300, bbox_inches='tight')
    plt.show()


def plot_communication_analysis(results_dict):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    methods = list(results_dict.keys())
    params = [results_dict[m][0].comm_details['parameters_m'] for m in methods]
    uplink = [results_dict[m][0].comm_details['uplink_mb'] for m in methods]
    downlink = [results_dict[m][0].comm_details['downlink_mb'] for m in methods]
    total_comm = [results_dict[m][0].comm_details['total_comm_mb'] for m in methods]
    client_times = [np.mean(results_dict[m][0].client_times) for m in methods]
    round_times = [np.mean(results_dict[m][3]) for m in methods]
    final_f1 = [results_dict[m][1][-1]['f1'] for m in methods]

    # Parameters
    axes[0, 0].bar([m.upper() for m in methods], params, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[0, 0].set_title('Model Parameters (M)', fontweight='bold')
    axes[0, 0].set_ylabel('Parameters (Millions)')
    axes[0, 0].tick_params(axis='x', rotation=15)

    # Communication costs
    x = np.arange(len(methods))
    width = 0.25
    axes[0, 1].bar(x - width, uplink, width, label='Uplink', color='#FF6B6B')
    axes[0, 1].bar(x, downlink, width, label='Downlink', color='#4ECDC4')
    axes[0, 1].bar(x + width, total_comm, width, label='Total', color='#45B7D1')
    axes[0, 1].set_title('Communication Costs per Round (MB)', fontweight='bold')
    axes[0, 1].set_xticks(x)
    axes[0, 1].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[0, 1].legend()

    # Timing
    axes[1, 0].bar(x - width/2, client_times, width, label='Client Time', color='#96CEB4')
    axes[1, 0].bar(x + width/2, round_times, width, label='Round Time', color='#F39C12')
    axes[1, 0].set_title('Training Times (seconds)', fontweight='bold')
    axes[1, 0].set_xticks(x)
    axes[1, 0].set_xticklabels([m.upper() for m in methods], rotation=15)
    axes[1, 0].legend()

    # Efficiency
    efficiency = [f1 / comm if comm > 0 else 0 for f1, comm in zip(final_f1, total_comm)]
    axes[1, 1].bar([m.upper() for m in methods], efficiency, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
    axes[1, 1].set_title('Communication Efficiency (F1/MB)', fontweight='bold')
    axes[1, 1].set_ylabel('F1 Score per MB')
    axes[1, 1].tick_params(axis='x', rotation=15)

    plt.tight_layout()
    plt.savefig('inceptionv3_communication_analysis.png', dpi=300, bbox_inches='tight')
    plt.show()


# ==== Main Experiment Runner ====
def run_complete_experiment(base_path):
    print("="*80)
    print("INCEPTIONV3 FEDERATED LEARNING EXPERIMENT - APTOS DATASET")
    print("="*80)

    # Setup dataset
    print("\nSetting up APTOS dataset...")
    train_ds, test_ds, class_names, class_weights, num_classes = setup_aptos_dataset_with_split(base_path)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False, num_workers=2)

    # Create non-IID client splits
    labels = np.array([y for _, y in train_ds.samples])
    client_indices = split_noniid_aptos(labels, n_clients=4, alpha=0.3)

    # Print client distribution
    print("\nClient Data Distribution:")
    for i, idx in enumerate(client_indices):
        client_labels = labels[idx]
        unique, counts = np.unique(client_labels, return_counts=True)
        class_dist = {class_names[u]: c for u, c in zip(unique, counts)}
        print(f"  Client {i+1}: {len(idx)} samples - {class_dist}")

    # Create client loaders
    client_loaders = []
    for idx in client_indices:
        client_labels = labels[idx]
        sample_weights = class_weights[client_labels]
        sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)
        loader = DataLoader(Subset(train_ds, idx), batch_size=16, sampler=sampler, num_workers=2)
        client_loaders.append(loader)

    # Run all experiments
    results = {}
    methods = ['fedavg', 'fedprox', 'moe']

    for method in methods:
        print(f"\n{'='*80}")
        print(f"EXPERIMENT: {method.upper()}")
        print(f"{'='*80}")

        model, history, comm, comp = run_fl_experiment(
            mode=method,
            rounds=20,
            local_epochs=3,
            lr=1e-4,  # InceptionV3 works well with lower learning rate
            client_loaders=client_loaders,
            test_loader=test_loader,
            class_weights=class_weights,
            client_indices=client_indices,
            class_names=class_names,
            num_experts=4
        )
        results[method] = (model, history, comm, comp)

        # Print summary
        final = history[-1]
        print(f"\n{method.upper()} Final Results:")
        print(f"  Accuracy: {final['accuracy']:.3f}")
        print(f"  F1-Score: {final['f1']:.3f}")
        print(f"  AUC-ROC: {final['auc_roc']:.3f}")
        if 'expert_entropy' in final:
            print(f"  Expert Entropy: {final['expert_entropy']:.2f}")

    # DP-FedAvg
    print(f"\n{'='*80}")
    print(f"EXPERIMENT: DP-FEDAVG")
    print(f"{'='*80}")

    model_dp, history_dp, comm_dp, comp_dp = run_fl_experiment(
        mode='dp_fedavg',
        rounds=20,
        local_epochs=3,
        lr=1e-4,
        client_loaders=client_loaders,
        test_loader=test_loader,
        class_weights=class_weights,
        client_indices=client_indices,
        class_names=class_names
    )
    results['dp_fedavg'] = (model_dp, history_dp, comm_dp, comp_dp)

    # Generate all visualizations
    print(f"\n{'='*80}")
    print("GENERATING VISUALIZATIONS AND ANALYSIS")
    print(f"{'='*80}")

    print("\n1. Plotting metrics comparison...")
    plot_metrics_comparison(results, class_names)

    print("2. Creating results table...")
    create_results_table(results)

    print("3. Plotting communication analysis...")
    plot_communication_analysis(results)

    # Find best model
    best_method = max(results.keys(), key=lambda x: results[x][1][-1]['f1'])
    best_model, best_history = results[best_method][:2]
    best_results = best_history[-1]

    print(f"\n{'='*80}")
    print(f"BEST PERFORMING METHOD: {best_method.upper()}")
    print(f"{'='*80}")
    print(f"\nFinal Performance Metrics:")
    print(f"  Accuracy:  {best_results['accuracy']:.3f}")
    print(f"  F1-Score:  {best_results['f1']:.3f}")
    print(f"  AUC-ROC:   {best_results['auc_roc']:.3f}")
    print(f"  Loss:      {best_results['loss']:.3f}")
    if 'expert_entropy' in best_results:
        print(f"  Expert Entropy: {best_results['expert_entropy']:.2f}")

    print("\n4. Plotting ROC curves...")
    plot_roc_curves(best_results, class_names)

    print("5. Plotting confusion matrix...")
    plot_confusion_matrix(best_results['y_true'], best_results['y_pred'], class_names)

    # Detailed classification report
    print(f"\n{'='*80}")
    print(f"DETAILED CLASSIFICATION REPORT - {best_method.upper()}")
    print(f"{'='*80}")
    print(classification_report(best_results['y_true'], best_results['y_pred'],
                                target_names=class_names, digits=3))

    # Per-class performance
    print(f"\nPer-Class Performance:")
    cm = confusion_matrix(best_results['y_true'], best_results['y_pred'])
    for i, class_name in enumerate(class_names):
        class_acc = cm[i, i] / cm[i].sum() if cm[i].sum() > 0 else 0
        print(f"  {class_name}: {class_acc:.3f} ({cm[i, i]}/{cm[i].sum()})")

    # Communication efficiency summary
    print(f"\n{'='*80}")
    print("COMMUNICATION EFFICIENCY COMPARISON")
    print(f"{'='*80}")
    print(f"\n{'Method':<15} {'Params(M)':<12} {'Comm(MB)':<12} {'F1':<8} {'Efficiency':<12}")
    print("-" * 70)
    for method, (model, history, _, _) in results.items():
        comm = model.comm_details
        f1 = history[-1]['f1']
        eff = f1 / comm['total_comm_mb'] if comm['total_comm_mb'] > 0 else 0
        print(f"{method.upper():<15} {comm['parameters_m']:<12.2f} {comm['total_comm_mb']:<12.2f} {f1:<8.3f} {eff:<12.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETED SUCCESSFULLY!")
    print(f"{'='*80}")
    print("\nGenerated files:")
    print("  - inceptionv3_metrics_comparison.png")
    print("  - inceptionv3_results_table.png")
    print("  - inceptionv3_communication_analysis.png")
    print("  - inceptionv3_roc_curves.png")
    print("  - inceptionv3_confusion_matrix.png")

    return results, best_model, best_method, class_names


# ==== RUN THE COMPLETE EXPERIMENT ====
if __name__ == "__main__":
    # Update this path to your APTOS dataset location
    BASE_PATH = "/content/drive/MyDrive/Tanjum/Retinopathy/Extract/APTOS/gaussian_filtered_images/gaussian_filtered_images"

    print("\n" + "="*80)
    print("STARTING INCEPTIONV3 FEDERATED LEARNING EXPERIMENT")
    print("="*80)
    print("\nThis will run:")
    print("  ✓ FedAvg")
    print("  ✓ FedProx")
    print("  ✓ FL-MOE (Mixture of Experts)")
    print("  ✓ DP-FedAvg (Differential Privacy)")
    print("\nAnd generate all metrics and visualizations...\n")

    results, best_model, best_method, class_names = run_complete_experiment(BASE_PATH)

    print(f"\n{'='*80}")
    print("ALL EXPERIMENTS COMPLETED!")
    print(f"{'='*80}")
    print(f"\nBest method: {best_method.upper()}")
    print("All results saved and visualizations generated.")
    print("\nKey Features of InceptionV3:")
    print("  • Multi-scale feature extraction with inception modules")
    print("  • 27M parameters (~45% of ResNet152)")
    print("  • Auxiliary classifier for better gradient flow")
    print("  • 299x299 input resolution for detailed features")
    print("  • Efficient computation with factorized convolutions")
# Out:
# ================================================================================
# STARTING INCEPTIONV3 FEDERATED LEARNING EXPERIMENT
# ================================================================================
#
# This will run:
#   ✓ FedAvg
#   ✓ FedProx
#   ✓ FL-MOE (Mixture of Experts)
#   ✓ DP-FedAvg (Differential Privacy)
#
# And generate all metrics and visualizations...
#
# ================================================================================
# INCEPTIONV3 FEDERATED LEARNING EXPERIMENT - APTOS DATASET
# ================================================================================
#
# Setting up APTOS dataset...
# Found classes: ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']
# Class 'Mild': 370 samples
# Class 'Moderate': 999 samples
# Class 'No_DR': 1805 samples
# Class 'Proliferate_DR': 295 samples
# Class 'Severe': 193 samples
#
# Dataset prepared:
#   Training samples: 2931
#   Test samples: 731
#
# Creating Non-IID split with alpha=0.3
#
# Client Data Distribution:
#   Client 1: 696 samples - {'Mild': 139, 'Moderate': 238, 'No_DR': 204, 'Proliferate_DR': 28, 'Severe': 87}
#   Client 2: 1461 samples - {'Mild': 132, 'Moderate': 330, 'No_DR': 998, 'Severe': 1}
#   Client 3: 268 samples - {'Mild': 7, 'Moderate': 48, 'No_DR': 1, 'Proliferate_DR': 207, 'Severe': 5}
#   Client 4: 506 samples - {'Mild': 18, 'Moderate': 184, 'No_DR': 241, 'Proliferate_DR': 1, 'Severe': 62}
#
# ================================================================================
# EXPERIMENT: FEDAVG
# ================================================================================
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00,

# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 12 | Acc: 0.475 | F1: 0.450 | AUC: 0.799 | Loss: 7.559 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 13 | Acc: 0.483 | F1: 0.457 | AUC: 0.813 | Loss: 7.451 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 14 | Acc: 0.494 | F1: 0.470 | AUC: 0.831 | Loss: 6.988 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 15 | Acc: 0.494 | F1: 0.465 | AUC: 0.822 | Loss: 7.337 | Client: 22.7s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 16 | Acc: 0.497 | F1: 0.471 | AUC: 0.835 | Loss: 7.402 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 17 | Acc: 0.505 | F1: 0.475 | AUC: 0.839 | Loss: 6.965 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 18 | Acc: 0.506 | F1: 0.477 | AUC: 0.837 | Loss: 7.214 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 19 | Acc: 0.503 | F1: 0.474 | AUC: 0.840 | Loss: 7.634 | Client: 22.5s
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Created InceptionV3 model
# Total parameters: 26,975,722
# Trainable parameters: 26,975,722
# Parameters (M): 26.98
# Model size: 102.90 MB
# Round 20 | Acc: 0.501 | F1: 0.471 | AUC: 0.839 | Loss: 7.520 | Client: 22.5s
#
# ================================================================================
# GENERATING VISUALIZATIONS AND ANALYSIS
# ================================================================================
#
# 1. Plotting metrics comparison...
# 2. Creating results table...
# 3. Plotting communication analysis...
# ================================================================================
# BEST PERFORMING METHOD: MOE
# ================================================================================
#
# Final Performance Metrics:
#   Accuracy:  0.598
#   F1-Score:  0.586
#   AUC-ROC:   0.807
#   Loss:      11.940
#   Expert Entropy: 1.14
#
# 4. Plotting ROC curves...
# 5. Plotting confusion matrix...
# ================================================================================
# DETAILED CLASSIFICATION REPORT - MOE
# ================================================================================
#                 precision    recall  f1-score   support
#
#           Mild      0.261     0.743     0.386        74
#       Moderate      0.557     0.246     0.341       199
#          No_DR      0.904     0.884     0.894       361
# Proliferate_DR      0.000     0.000     0.000        59
#         Severe      0.177     0.368     0.239        38
#
#       accuracy                          0.598       731
#      macro avg      0.380     0.448     0.372       731
#   weighted avg      0.633     0.598     0.586       731
#
#
# Per-Class Performance:
#   Mild: 0.743 (55/74)
#   Moderate: 0.246 (49/199)
#   No_DR: 0.884 (319/361)
#   Proliferate_DR: 0.000 (0/59)
#   Severe: 0.368 (14/38)
#
# ================================================================================
# COMMUNICATION EFFICIENCY COMPARISON
# ================================================================================
#
# Method          Params(M)    Comm(MB)     F1       Efficiency
# ----------------------------------------------------------------------
# FEDAVG          26.98        205.81       0.490    0.0024
# FEDPROX         26.98        205.81       0.525    0.0026
# MOE             36.97        282.07       0.586    0.0021
# DP_FEDAVG       26.98        205.81       0.471    0.0023
#
# ================================================================================
# EXPERIMENT COMPLETED SUCCESSFULLY!
# ================================================================================
#
# Generated files:
#   - inceptionv3_metrics_comparison.png
#   - inceptionv3_results_table.png
#   - inceptionv3_communication_analysis.png
#   - inceptionv3_roc_curves.png
#   - inceptionv3_confusion_matrix.png
#
# ================================================================================
# ALL EXPERIMENTS COMPLETED!
# ================================================================================
#
# Best method: MOE
# All results saved and visualizations generated.
#
# Key Features of InceptionV3:
#   • Multi-scale feature extraction with inception modules
#   • 27M parameters (~45% of ResNet152)
#   • Auxiliary classifier for better gradient flow
#   • 299x299 input resolution for detailed features
#   • Efficient computation with factorized convolutions
